# %% [markdown]
# Librerías

# %%
import pandas as pd
from inline_sql import sql

# %% [markdown]
# Dataframes

# %%
path = "./TablasLimpias/"

provincia = pd.read_csv(path+"provincia.csv", index_col=0)
departamento = pd.read_csv(path+"departamento.csv", index_col=0)
establecimiento_productivo = pd.read_csv(path+"establecimiento_productivo.csv", index_col=0)
operador_organico = pd.read_csv(path+"operador_organico.csv", index_col=0)
productos = pd.read_csv(path+"productos.csv", index_col=0)
operador_produce = pd.read_csv(path+"operador_produce.csv", index_col=0)
rubro = pd.read_csv(path+"rubro.csv", index_col=0)

# %%
establecimiento_productivo.shape
# Out:
# (706498, 4)

# %% [markdown]
# #Ejercicios

# %%
#FUNCION PARA PASAR A LATEX LAS TABLES

def pasar_latex(tabla):
  tabla_latex = tabla.to_latex(index=False)
  print(tabla_latex)

# %% [markdown]
# ### **i)** Para cada producto (producido por un productor orgánico) detallar en qué provincias se produce. El orden del reporte debe respetar la cantidad de provincias en las cuales se produce dicho producto (de mayor a menor). En caso de empate, ordenar alfabéticamente por nombre de producto.

# %%
#hacemos una query para relacionar cada producto con su nombre y el id de su operador
query_aux = """
             SELECT r.ID_operador, p.Nombre AS Producto
             FROM operador_produce AS r
             INNER JOIN productos AS p
             ON r.ID_producto = p.ID_producto
            """

producto_operador = sql^ query_aux

#ahora lo conectamos con el departamento del operador
query_aux_2 = """
                SELECT op.ID_departamento AS id_departamento, p.ID_operador, p.Producto
                FROM producto_operador AS p
                INNER JOIN operador_organico AS op
                ON p.ID_operador = op.ID_operador
              """

producto_operador_depto = sql^ query_aux_2

#ahora lo relacionamos con el id de la provincia
query_aux_3 = """
               SELECT DISTINCT d.ID_provincia,
               op.Producto
               FROM producto_operador_depto AS op
               INNER JOIN departamento AS d
               ON op.ID_departamento = d.ID_departamento
              """

producto_operador_depto_provincia = sql^ query_aux_3

#ya tenemos filas con el operador, los productos y la provincia donde se producen.
#necesitamos saber la cantidad de provincias en que se produce cada producto

query_provincias_por_producto = """
                                 SELECT Producto, COUNT(ID_provincia) AS cant_provincias
                                 FROM producto_operador_depto_provincia
                                 GROUP BY Producto
                                """

#el DISTINCT en la subquery principal es porque no queremos que se cuente dos veces,
#por ejemplo: "CAÑA DE AZUCAR, MISIONES" porque lo producen dos operadores, lo que nos importa
#es la cantidad de provincias en donde lo producen

temp_cant_provincias_por_producto = sql^query_provincias_por_producto

#tenemos la cantidad de provincias en las que se produce cada producto, pasamos a
#enlazar la query anterior a ésta con el resultado de ejecutar la de arriba

query_aux_4 = """
                SELECT p.Nombre AS Provincia,
                r.Producto
                FROM producto_operador_depto_provincia AS r
                INNER JOIN provincia AS p
                ON p.ID_provincia = r.ID_provincia
              """

temp_productos_y_provincias_donde_estan = sql^query_aux_4

#ya podemos conectar todo

query = """
          SELECT DISTINCT p.Producto, p.Provincia
          FROM temp_productos_y_provincias_donde_estan AS p
          INNER JOIN temp_cant_provincias_por_producto AS c
          ON p.Producto = c.Producto
          ORDER BY c.cant_provincias DESC, p.Producto
        """

provincias_productos_producidos = sql^query

# %%
provincias_productos_producidos.head()
# Out:
#   Producto     Provincia
# 0  INCULTO  BUENOS AIRES
# 1  INCULTO       TUCUMAN
# 2  INCULTO      SAN LUIS
# 3  INCULTO      SAN JUAN
# 4  INCULTO         SALTA

# %%
pasar_latex(provincias_productos_producidos.head())
# Out:
# \begin{tabular}{ll}
# \toprule
# Producto &    Provincia \\
# \midrule
#  INCULTO & BUENOS AIRES \\
#  INCULTO &      TUCUMAN \\
#  INCULTO &     SAN LUIS \\
#  INCULTO &     SAN JUAN \\
#  INCULTO &        SALTA \\
# \bottomrule
# \end{tabular}
# C:\Users\luisr\AppData\Local\Temp\ipykernel_16792\4273561937.py:4: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   tabla_latex = tabla.to_latex(index=False)

# %%
provincias_productos_producidos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 795 entries, 0 to 794
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Producto   795 non-null    object
#  1   Provincia  795 non-null    object
# dtypes: object(2)
# memory usage: 12.5+ KB

# %%
pasar_latex(provincias_productos_producidos)
# Out:
# C:\Users\luisr\AppData\Local\Temp\ipykernel_16792\4273561937.py:4: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   tabla_latex = tabla.to_latex(index=False)
# \begin{tabular}{ll}
# \toprule
#                                Producto &                       Provincia \\
# \midrule
#                                 INCULTO &                    BUENOS AIRES \\
#                                 INCULTO &                         TUCUMAN \\
#                                 INCULTO &                        SAN LUIS \\
#                                 INCULTO &                        SAN JUAN \\
#                                 INCULTO &                           SALTA \\
#                                 INCULTO &                       RIO NEGRO \\
#                                 INCULTO &                         MENDOZA \\
#                                 INCULTO &                           JUJUY \\
#                                 INCULTO &                         FORMOSA \\
#                                 INCULTO &                      ENTRE RIOS \\
#                                 INCULTO &                           CHACO \\
#                                 INCULTO &                      CORRIENTES \\
#                                 INCULTO &                       CATAMARCA \\
#                                   MONTE &                      CORRIENTES \\
#                                   MONTE &                        SAN JUAN \\
#                                   MONTE &                    BUENOS AIRES \\
#                                   MONTE &                         MENDOZA \\
#                                   MONTE &                           JUJUY \\
#                                   MONTE &                         TUCUMAN \\
#                                   MONTE &                      ENTRE RIOS \\
#                                   MONTE &                        LA RIOJA \\
#                                   MONTE &                        MISIONES \\
#                                   MONTE &                       RIO NEGRO \\
#                                   MONTE &                           SALTA \\
#                                   MONTE &                        SAN LUIS \\
#                                   MONTE &                          CHUBUT \\
#                                 BOVINOS &                       RIO NEGRO \\
#                                 BOVINOS & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                 BOVINOS &                           SALTA \\
#                                 BOVINOS &                        SANTA FE \\
#                                 BOVINOS &                        MISIONES \\
#                                 BOVINOS &                    BUENOS AIRES \\
#                                 BOVINOS &                         CORDOBA \\
#                                 BOVINOS &                          CHUBUT \\
#                                 BOVINOS &                      SANTA CRUZ \\
#                                 BOVINOS &                      ENTRE RIOS \\
#                                 BOVINOS &                        SAN LUIS \\
#                                 BOVINOS &                TIERRA DEL FUEGO \\
#                                 ZAPALLO &                        SAN LUIS \\
#                                 ZAPALLO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                 ZAPALLO &                         CORDOBA \\
#                                 ZAPALLO &                    BUENOS AIRES \\
#                                 ZAPALLO &                        SAN JUAN \\
#                                 ZAPALLO &                        LA RIOJA \\
#                                 ZAPALLO &                         MENDOZA \\
#                                 ZAPALLO &                      ENTRE RIOS \\
#                                 ZAPALLO &                         NEUQUEN \\
#                                 ZAPALLO &                       RIO NEGRO \\
#                                 ZAPALLO &                           CHACO \\
#                          AZUCAR DE CAÑA &                           SALTA \\
#                          AZUCAR DE CAÑA &                           JUJUY \\
#                          AZUCAR DE CAÑA &                        MISIONES \\
#                          AZUCAR DE CAÑA &                        LA RIOJA \\
#                          AZUCAR DE CAÑA &                         MENDOZA \\
#                          AZUCAR DE CAÑA &                    BUENOS AIRES \\
#                          AZUCAR DE CAÑA &                         CORDOBA \\
#                          AZUCAR DE CAÑA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                          AZUCAR DE CAÑA &                      ENTRE RIOS \\
#                          AZUCAR DE CAÑA &                         TUCUMAN \\
#                           CAMPO NATURAL &                           CHACO \\
#                           CAMPO NATURAL &                          CHUBUT \\
#                           CAMPO NATURAL &                      ENTRE RIOS \\
#                           CAMPO NATURAL &                           SALTA \\
#                           CAMPO NATURAL &                        SAN JUAN \\
#                           CAMPO NATURAL &                    BUENOS AIRES \\
#                           CAMPO NATURAL &                           JUJUY \\
#                           CAMPO NATURAL &                      CORRIENTES \\
#                           CAMPO NATURAL &                         MENDOZA \\
#                                   VACAS &                      SANTA CRUZ \\
#                                   VACAS &                    BUENOS AIRES \\
#                                   VACAS &                         CORDOBA \\
#                                   VACAS &                          CHUBUT \\
#                                   VACAS &                      ENTRE RIOS \\
#                                   VACAS &                       RIO NEGRO \\
#                                   VACAS &                        SAN LUIS \\
#                                   VACAS &                TIERRA DEL FUEGO \\
#                                   VACAS &                        MISIONES \\
#                             VAQUILLONAS &                    BUENOS AIRES \\
#                             VAQUILLONAS &                TIERRA DEL FUEGO \\
#                             VAQUILLONAS &                      SANTA CRUZ \\
#                             VAQUILLONAS &                        SAN LUIS \\
#                             VAQUILLONAS &                         CORDOBA \\
#                             VAQUILLONAS &                       RIO NEGRO \\
#                             VAQUILLONAS &                      ENTRE RIOS \\
#                             VAQUILLONAS &                          CHUBUT \\
#                             VAQUILLONAS &                        MISIONES \\
#                                CEREALES &                       RIO NEGRO \\
#                                CEREALES & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                CEREALES &                         CORDOBA \\
#                                CEREALES &                    BUENOS AIRES \\
#                                CEREALES &                        SANTA FE \\
#                                CEREALES &                           SALTA \\
#                                CEREALES &             SANTIAGO DEL ESTERO \\
#                                CEREALES &                      ENTRE RIOS \\
#                                    CHIA &                         CORDOBA \\
#                                    CHIA &                       CATAMARCA \\
#                                    CHIA &                           SALTA \\
#                                    CHIA &                           JUJUY \\
#                                    CHIA &                         TUCUMAN \\
#                                    CHIA &                    BUENOS AIRES \\
#                                    CHIA &                      ENTRE RIOS \\
#                                    CHIA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                 CIRUELA &                         MENDOZA \\
#                                 CIRUELA &                       RIO NEGRO \\
#                                 CIRUELA &                      ENTRE RIOS \\
#                                 CIRUELA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                 CIRUELA &                         CORDOBA \\
#                                 CIRUELA &                         NEUQUEN \\
#                                 CIRUELA &                        SAN JUAN \\
#                                 CIRUELA &                    BUENOS AIRES \\
#                                 DURAZNO &                         CORDOBA \\
#                                 DURAZNO &                      ENTRE RIOS \\
#                                 DURAZNO &                        SAN JUAN \\
#                                 DURAZNO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                 DURAZNO &                    BUENOS AIRES \\
#                                 DURAZNO &                         MENDOZA \\
#                                 DURAZNO &                         NEUQUEN \\
#                                 DURAZNO &                       RIO NEGRO \\
#                 FRACCIONAMIENTO DE MIEL &                      ENTRE RIOS \\
#                 FRACCIONAMIENTO DE MIEL &                         MENDOZA \\
#                 FRACCIONAMIENTO DE MIEL &                         CORDOBA \\
#                 FRACCIONAMIENTO DE MIEL &                    BUENOS AIRES \\
#                 FRACCIONAMIENTO DE MIEL & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                 FRACCIONAMIENTO DE MIEL &             SANTIAGO DEL ESTERO \\
#                 FRACCIONAMIENTO DE MIEL &                        SANTA FE \\
#                 FRACCIONAMIENTO DE MIEL &                           CHACO \\
#                                    MAIZ &                           SALTA \\
#                                    MAIZ &                    BUENOS AIRES \\
#                                    MAIZ &                         CORDOBA \\
#                                    MAIZ &                      ENTRE RIOS \\
#                                    MAIZ &                        SANTA FE \\
#                                    MAIZ &                        LA RIOJA \\
#                                    MAIZ & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                    MAIZ &                        SAN LUIS \\
#                             OELAGINOSAS &                    BUENOS AIRES \\
#                             OELAGINOSAS &                         CORDOBA \\
#                             OELAGINOSAS &                        SANTA FE \\
#                             OELAGINOSAS &                       RIO NEGRO \\
#                             OELAGINOSAS & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                             OELAGINOSAS &                           SALTA \\
#                             OELAGINOSAS &                      ENTRE RIOS \\
#                             OELAGINOSAS &             SANTIAGO DEL ESTERO \\
#                                    PERA &                         NEUQUEN \\
#                                    PERA &                        SANTA FE \\
#                                    PERA &                         MENDOZA \\
#                                    PERA &                        SAN JUAN \\
#                                    PERA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                    PERA &                       RIO NEGRO \\
#                                    PERA &                    BUENOS AIRES \\
#                                  POROTO &                        LA PAMPA \\
#                                  POROTO &                           JUJUY \\
#                                  POROTO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                  POROTO &                        MISIONES \\
#                                  POROTO &                         CORDOBA \\
#                                  POROTO &                         TUCUMAN \\
#                                  POROTO &                           SALTA \\
#                                TE VERDE &                        LA RIOJA \\
#                                TE VERDE &                    BUENOS AIRES \\
#                                TE VERDE &                        MISIONES \\
#                                TE VERDE &                      ENTRE RIOS \\
#                                TE VERDE &                         MENDOZA \\
#                                TE VERDE &                        SAN JUAN \\
#                                TE VERDE &                         CORDOBA \\
#                         ACEITE DE OLIVA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                         ACEITE DE OLIVA &                         CORDOBA \\
#                         ACEITE DE OLIVA &                         MENDOZA \\
#                         ACEITE DE OLIVA &                       CATAMARCA \\
#                         ACEITE DE OLIVA &                        LA RIOJA \\
#                         ACEITE DE OLIVA &                    BUENOS AIRES \\
#                                     AJO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                     AJO &                      ENTRE RIOS \\
#                                     AJO &                        SAN LUIS \\
#                                     AJO &                        SAN JUAN \\
#                                     AJO &                         MENDOZA \\
#                                     AJO &                    BUENOS AIRES \\
#                                ARANDANO &                    BUENOS AIRES \\
#                                ARANDANO &                          CHUBUT \\
#                                ARANDANO &                         TUCUMAN \\
#                                ARANDANO &                      ENTRE RIOS \\
#                                ARANDANO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                ARANDANO &                       RIO NEGRO \\
#                              AROMATICAS &                         CORDOBA \\
#                              AROMATICAS &                         MENDOZA \\
#                              AROMATICAS &                        MISIONES \\
#                              AROMATICAS &                           SALTA \\
#                              AROMATICAS &                        SANTA FE \\
#                              AROMATICAS &             SANTIAGO DEL ESTERO \\
#                                  CEREZA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                  CEREZA &                         MENDOZA \\
#                                  CEREZA &                       RIO NEGRO \\
#                                  CEREZA &                          CHUBUT \\
#                                  CEREZA &                         NEUQUEN \\
#                                  CEREZA &                        SAN JUAN \\
#                              ESPUMANTES &                           SALTA \\
#                              ESPUMANTES &                       CATAMARCA \\
#                              ESPUMANTES &                        LA RIOJA \\
#                              ESPUMANTES &                         MENDOZA \\
#                              ESPUMANTES &                        SAN JUAN \\
#                              ESPUMANTES & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                 GIRASOL &                      ENTRE RIOS \\
#                                 GIRASOL &                         CORDOBA \\
#                                 GIRASOL &                    BUENOS AIRES \\
#                                 GIRASOL &                        LA PAMPA \\
#                                 GIRASOL & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                 GIRASOL &                        SANTA FE \\
#                                   LIMON &                        SAN JUAN \\
#                                   LIMON &                    BUENOS AIRES \\
#                                   LIMON &                         TUCUMAN \\
#                                   LIMON &                      CORRIENTES \\
#                                   LIMON &                      ENTRE RIOS \\
#                                   LIMON &                        MISIONES \\
#                               MANDARINA &                        MISIONES \\
#                               MANDARINA &                         TUCUMAN \\
#                               MANDARINA &                      CORRIENTES \\
#                               MANDARINA &                    BUENOS AIRES \\
#                               MANDARINA &                      ENTRE RIOS \\
#                               MANDARINA &                        SAN JUAN \\
#                                 MANZANA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                 MANZANA &                         MENDOZA \\
#                                 MANZANA &                         NEUQUEN \\
#                                 MANZANA &                        SAN JUAN \\
#                                 MANZANA &                       RIO NEGRO \\
#                                 MANZANA &                    BUENOS AIRES \\
#                                 NARANJA &                         TUCUMAN \\
#                                 NARANJA &                      ENTRE RIOS \\
#                                 NARANJA &                        MISIONES \\
#                                 NARANJA &                        SAN JUAN \\
#                                 NARANJA &                      CORRIENTES \\
#                                 NARANJA &                    BUENOS AIRES \\
#                                    NUEZ &                         MENDOZA \\
#                                    NUEZ &                        SAN JUAN \\
#                                    NUEZ & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                    NUEZ &                       RIO NEGRO \\
#                                    NUEZ &                      ENTRE RIOS \\
#                                    NUEZ &                    BUENOS AIRES \\
#                                   OLIVA &                         CORDOBA \\
#                                   OLIVA &                         MENDOZA \\
#                                   OLIVA &                        LA RIOJA \\
#                                   OLIVA &                    BUENOS AIRES \\
#                                   OLIVA &                       CATAMARCA \\
#                                   OLIVA &                        SAN JUAN \\
#                                   TRIGO &                    BUENOS AIRES \\
#                                   TRIGO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                   TRIGO &                         CORDOBA \\
#                                   TRIGO &                      ENTRE RIOS \\
#                                   TRIGO &                           JUJUY \\
#                                   TRIGO &                        SANTA FE \\
#                                      VD &                       CATAMARCA \\
#                                      VD &                        LA RIOJA \\
#                                      VD &                         MENDOZA \\
#                                      VD &                       RIO NEGRO \\
#                                      VD &                           SALTA \\
#                                      VD &                        SAN JUAN \\
#                               ACEITUNAS & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                               ACEITUNAS &                        SAN JUAN \\
#                               ACEITUNAS &                        LA RIOJA \\
#                               ACEITUNAS &                         CORDOBA \\
#                               ACEITUNAS &                         MENDOZA \\
#                            ALZA MELARIA &                         CORDOBA \\
#                            ALZA MELARIA &                    BUENOS AIRES \\
#                            ALZA MELARIA &                           CHACO \\
#                            ALZA MELARIA &                           JUJUY \\
#                            ALZA MELARIA &                        LA PAMPA \\
#                                   ARROZ &                    BUENOS AIRES \\
#                                   ARROZ & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                   ARROZ &                      ENTRE RIOS \\
#                                   ARROZ &                           CHACO \\
#                                   ARROZ &                      CORRIENTES \\
#                                 CEBOLLA &                         CORDOBA \\
#                                 CEBOLLA &                    BUENOS AIRES \\
#                                 CEBOLLA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                 CEBOLLA &                        SAN LUIS \\
#                                 CEBOLLA &                         MENDOZA \\
#                                 CENTENO &                    BUENOS AIRES \\
#                                 CENTENO &                      ENTRE RIOS \\
#                                 CENTENO &                         MENDOZA \\
#                                 CENTENO &                         CORDOBA \\
#                                 CENTENO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                  CONGELADO DE FRUTILLAS &                          CHUBUT \\
#                  CONGELADO DE FRUTILLAS & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                  CONGELADO DE FRUTILLAS &                         TUCUMAN \\
#                  CONGELADO DE FRUTILLAS &                    BUENOS AIRES \\
#                  CONGELADO DE FRUTILLAS &                        SANTA FE \\
#                                 DAMASCO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                 DAMASCO &                         MENDOZA \\
#                                 DAMASCO &                        SAN JUAN \\
#                                 DAMASCO &                         NEUQUEN \\
#                                 DAMASCO &                       RIO NEGRO \\
#                                DESCANSO &                         MENDOZA \\
#                                DESCANSO &                       RIO NEGRO \\
#                                DESCANSO &                      CORRIENTES \\
#                                DESCANSO &                    BUENOS AIRES \\
#                                DESCANSO &                           SALTA \\
#                               FRAMBUESA &                         TUCUMAN \\
#                               FRAMBUESA &                    BUENOS AIRES \\
#                               FRAMBUESA &                        SAN LUIS \\
#                               FRAMBUESA &                       RIO NEGRO \\
#                               FRAMBUESA &                          CHUBUT \\
#                                NOVILLOS &                      ENTRE RIOS \\
#                                NOVILLOS &                    BUENOS AIRES \\
#                                NOVILLOS &                          CHUBUT \\
#                                NOVILLOS &                TIERRA DEL FUEGO \\
#                                NOVILLOS &                       RIO NEGRO \\
#                                   PASAS &                        LA RIOJA \\
#                                   PASAS &                        SAN JUAN \\
#                                   PASAS &                        SANTA FE \\
#                                   PASAS & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                   PASAS &                       CATAMARCA \\
#                                  POMELO &                         FORMOSA \\
#                                  POMELO &                        SAN JUAN \\
#                                  POMELO &                      ENTRE RIOS \\
#                                  POMELO &                    BUENOS AIRES \\
#                                  POMELO &                        MISIONES \\
#                                  SESAMO &                         CORDOBA \\
#                                  SESAMO &                           JUJUY \\
#                                  SESAMO &                    BUENOS AIRES \\
#                                  SESAMO &                         TUCUMAN \\
#                                  SESAMO &                           SALTA \\
#                                    SOJA &                    BUENOS AIRES \\
#                                    SOJA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                    SOJA &                      ENTRE RIOS \\
#                                    SOJA &                        SANTA FE \\
#                                    SOJA &                         CORDOBA \\
#              SUBPRODUCTOS DE LA COLMENA &             SANTIAGO DEL ESTERO \\
#              SUBPRODUCTOS DE LA COLMENA &                    BUENOS AIRES \\
#              SUBPRODUCTOS DE LA COLMENA &                        SANTA FE \\
#              SUBPRODUCTOS DE LA COLMENA &                         CORDOBA \\
#              SUBPRODUCTOS DE LA COLMENA &                           CHACO \\
#                                     UVA &                        SAN JUAN \\
#                                     UVA &                       RIO NEGRO \\
#                                     UVA &                         MENDOZA \\
#                                     UVA &                       CATAMARCA \\
#                                     UVA &                           SALTA \\
#                                 ALFALFA &                    BUENOS AIRES \\
#                                 ALFALFA &                           SALTA \\
#                                 ALFALFA &                         MENDOZA \\
#                                 ALFALFA &                         CORDOBA \\
#                                  CEBADA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                  CEBADA &                         CORDOBA \\
#                                  CEBADA &                    BUENOS AIRES \\
#                                  CEBADA &                      ENTRE RIOS \\
#                                COLMENAS &                        LA PAMPA \\
#                                COLMENAS &                           CHACO \\
#                                COLMENAS &                         CORDOBA \\
#                                COLMENAS &                    BUENOS AIRES \\
#                               ESPARRAGO &                        SAN JUAN \\
#                               ESPARRAGO &                         MENDOZA \\
#                               ESPARRAGO &                    BUENOS AIRES \\
#                               ESPARRAGO &                         CORDOBA \\
#                                FRUTALES &             SANTIAGO DEL ESTERO \\
#                                FRUTALES &                    BUENOS AIRES \\
#                                FRUTALES &                        SANTA FE \\
#                                FRUTALES &                      ENTRE RIOS \\
#                         GANADERIA OVINA &                      SANTA CRUZ \\
#                         GANADERIA OVINA &                       RIO NEGRO \\
#                         GANADERIA OVINA &                    BUENOS AIRES \\
#                         GANADERIA OVINA &                          CHUBUT \\
#                                GARBANZO &                    BUENOS AIRES \\
#                                GARBANZO &                         TUCUMAN \\
#                                GARBANZO &                         CORDOBA \\
#                                GARBANZO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                    HIGO &                         MENDOZA \\
#                                    HIGO &                        SANTA FE \\
#                                    HIGO &                    BUENOS AIRES \\
#                                    HIGO &                        SAN JUAN \\
#                              HORTALIZAS &                         MENDOZA \\
#                              HORTALIZAS &                    BUENOS AIRES \\
#                              HORTALIZAS &             SANTIAGO DEL ESTERO \\
#                              HORTALIZAS &                        SANTA FE \\
#                              LANA SUCIA &                          CHUBUT \\
#                              LANA SUCIA &                       RIO NEGRO \\
#                              LANA SUCIA &                      SANTA CRUZ \\
#                              LANA SUCIA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                   NOGAL &                        LA RIOJA \\
#                                   NOGAL &                    BUENOS AIRES \\
#                                   NOGAL &                         MENDOZA \\
#                                   NOGAL &                       RIO NEGRO \\
#                                 NUCLEOS &                           CHACO \\
#                                 NUCLEOS &                        LA PAMPA \\
#                                 NUCLEOS &                         CORDOBA \\
#                                 NUCLEOS &                    BUENOS AIRES \\
#                                 OREGANO &                         CORDOBA \\
#                                 OREGANO &                        SAN LUIS \\
#                                 OREGANO &                       CATAMARCA \\
#                                 OREGANO &                    BUENOS AIRES \\
#                        PASTOS NATURALES &                           SALTA \\
#                        PASTOS NATURALES &                    BUENOS AIRES \\
#                        PASTOS NATURALES &                        SAN LUIS \\
#                        PASTOS NATURALES &                        SANTA FE \\
#                                   SORGO &                      ENTRE RIOS \\
#                                   SORGO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                   SORGO &                        SANTA FE \\
#                                   SORGO &                    BUENOS AIRES \\
#                               ZANAHORIA &                         CORDOBA \\
#                               ZANAHORIA &                    BUENOS AIRES \\
#                               ZANAHORIA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                               ZANAHORIA &                         MENDOZA \\
#                          ACEITE DE SOJA &                         CORDOBA \\
#                          ACEITE DE SOJA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                          ACEITE DE SOJA &                    BUENOS AIRES \\
#                                  ACELGA &                    BUENOS AIRES \\
#                                  ACELGA &                         CORDOBA \\
#                                  ACELGA &                        SAN JUAN \\
#                      ARANDANO CONGELADO &                         TUCUMAN \\
#                      ARANDANO CONGELADO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                      ARANDANO CONGELADO &                    BUENOS AIRES \\
#                                  BATATA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                  BATATA &                        LA RIOJA \\
#                                  BATATA &                    BUENOS AIRES \\
#                                BORREGAS &                      SANTA CRUZ \\
#                                BORREGAS &                          CHUBUT \\
#                                BORREGAS &                       RIO NEGRO \\
#                                 BROCOLI &                         MENDOZA \\
#                                 BROCOLI &                        SAN JUAN \\
#                                 BROCOLI &                    BUENOS AIRES \\
#                                 CAPONES &                      SANTA CRUZ \\
#                                 CAPONES &                          CHUBUT \\
#                                 CAPONES &                       RIO NEGRO \\
#                                CARNEROS &                       RIO NEGRO \\
#                                CARNEROS &                      SANTA CRUZ \\
#                                CARNEROS &                          CHUBUT \\
#                                    CERA &                         CORDOBA \\
#                                    CERA &                           CHACO \\
#                                    CERA &                    BUENOS AIRES \\
#                                CORDEROS &                          CHUBUT \\
#                                CORDEROS &                       RIO NEGRO \\
#                                CORDEROS &                      SANTA CRUZ \\
#                                ESPINACA &                    BUENOS AIRES \\
#                                ESPINACA &                         CORDOBA \\
#                                ESPINACA &                        SAN JUAN \\
#                                    JUGO &                         TUCUMAN \\
#                                    JUGO &                        SANTA FE \\
#                                    JUGO &                       RIO NEGRO \\
#                                 LECHUGA &                        SAN JUAN \\
#                                 LECHUGA &                    BUENOS AIRES \\
#                                 LECHUGA &                         CORDOBA \\
#                             LEGUMINOSAS &             SANTIAGO DEL ESTERO \\
#                             LEGUMINOSAS &                           SALTA \\
#                             LEGUMINOSAS &                         CORDOBA \\
#                                    LINO &                      ENTRE RIOS \\
#                                    LINO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                    LINO &                    BUENOS AIRES \\
#                             MATE COCIDO &                        MISIONES \\
#                             MATE COCIDO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                             MATE COCIDO &                    BUENOS AIRES \\
#                                   MELON &                         CORDOBA \\
#                                   MELON &                        LA RIOJA \\
#                                   MELON &                        SAN JUAN \\
#                               MEMBRILLO &                       RIO NEGRO \\
#                               MEMBRILLO &                        SAN JUAN \\
#                               MEMBRILLO &                         MENDOZA \\
#                                    MIJO &                    BUENOS AIRES \\
#                                    MIJO &                      ENTRE RIOS \\
#                                    MIJO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                    MORA &                    BUENOS AIRES \\
#                                    MORA &                         TUCUMAN \\
#                                    MORA &                          CHUBUT \\
#                                  NUECES &                         MENDOZA \\
#                                  NUECES &                       RIO NEGRO \\
#                                  NUECES &                           SALTA \\
#              OTROS PRODUCTOS ORGANICOS. &                    BUENOS AIRES \\
#              OTROS PRODUCTOS ORGANICOS. & CIUDAD AUTONOMA DE BUENOS AIRES \\
#              OTROS PRODUCTOS ORGANICOS. &                         CORDOBA \\
#                            PURE DE PERA &                         MENDOZA \\
#                            PURE DE PERA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                            PURE DE PERA &                       RIO NEGRO \\
#                               REMOLACHA &                         CORDOBA \\
#                               REMOLACHA &                    BUENOS AIRES \\
#                               REMOLACHA &                        SAN JUAN \\
#                                  ROMERO &                        SAN LUIS \\
#                                  ROMERO &                    BUENOS AIRES \\
#                                  ROMERO &                         CORDOBA \\
#                                 TOMILLO &                    BUENOS AIRES \\
#                                 TOMILLO &                        SAN LUIS \\
#                                 TOMILLO &                         CORDOBA \\
#                             ABONO VERDE &                         MENDOZA \\
#                             ABONO VERDE &                    BUENOS AIRES \\
#                         ACEITE DE COLZA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                         ACEITE DE COLZA &                    BUENOS AIRES \\
#                  ACEITE DE COLZA CANOLA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                  ACEITE DE COLZA CANOLA &                    BUENOS AIRES \\
#                       ACEITE DE GIRASOL & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                       ACEITE DE GIRASOL &                    BUENOS AIRES \\
#                        ACEITE DE JOJOBA &                        LA RIOJA \\
#                        ACEITE DE JOJOBA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                     ACEITE DE MANDARINA &                      ENTRE RIOS \\
#                     ACEITE DE MANDARINA &                      CORRIENTES \\
#                ACEITE ESENCIAL DE LIMON &                      CORRIENTES \\
#                ACEITE ESENCIAL DE LIMON &                      ENTRE RIOS \\
#              ACEITE ESENCIAL DE NARANJA &                      ENTRE RIOS \\
#              ACEITE ESENCIAL DE NARANJA &                      CORRIENTES \\
#               ACEITE ESENCIAL DE POMELO &                      ENTRE RIOS \\
#               ACEITE ESENCIAL DE POMELO &                      CORRIENTES \\
#                      ACOPIO DE CEREALES &                    BUENOS AIRES \\
#                      ACOPIO DE CEREALES &                      ENTRE RIOS \\
#                                ALCAUCIL &                    BUENOS AIRES \\
#                                ALCAUCIL &                        SAN JUAN \\
#                                 ALCOHOL &                           SALTA \\
#                                 ALCOHOL & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                               ALMENDRAS &                       RIO NEGRO \\
#                               ALMENDRAS &                        SAN JUAN \\
#                                    APIO &                         CORDOBA \\
#                                    APIO &                    BUENOS AIRES \\
#                                  ARVEJA &                         CORDOBA \\
#                                  ARVEJA &                    BUENOS AIRES \\
#                               AVELLANAS &                       RIO NEGRO \\
#                               AVELLANAS &                        SAN JUAN \\
#                                   AVENA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                   AVENA &                    BUENOS AIRES \\
#                                  AZUCAR &                        SANTA FE \\
#                                  AZUCAR &                      ENTRE RIOS \\
#                                 BLOUSSE & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                 BLOUSSE &                          CHUBUT \\
#                                  CANOLA &                    BUENOS AIRES \\
#                                  CANOLA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                 CAPUERA &                           SALTA \\
#                                 CAPUERA &                        MISIONES \\
#                                  CASSIS &                       RIO NEGRO \\
#                                  CASSIS &                          CHUBUT \\
#                       CEBOLLA DE VERDEO &                    BUENOS AIRES \\
#                       CEBOLLA DE VERDEO &                         CORDOBA \\
#                                 CHAUCHA &                         CORDOBA \\
#                                 CHAUCHA &                    BUENOS AIRES \\
#                                  CHOCLO &                         CORDOBA \\
#                                  CHOCLO &                         MENDOZA \\
#                                CILANTRO &                         CORDOBA \\
#                                CILANTRO &                    BUENOS AIRES \\
#                        CIRUELA DESECADA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                        CIRUELA DESECADA &                         MENDOZA \\
#                                   COLZA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                   COLZA &                    BUENOS AIRES \\
#                                 CORINTO &                       RIO NEGRO \\
#                                 CORINTO &                          CHUBUT \\
#               ELAB ACEITE ROSA MOSQUETA &                          CHUBUT \\
#               ELAB ACEITE ROSA MOSQUETA &                       RIO NEGRO \\
#                                ESCAROLA &                    BUENOS AIRES \\
#                                ESCAROLA &                         CORDOBA \\
#                        EXPELLER DE SOJA &                         CORDOBA \\
#                        EXPELLER DE SOJA &                    BUENOS AIRES \\
#                              FORESTALES &                         MENDOZA \\
#                              FORESTALES &                    BUENOS AIRES \\
#                     FRAMBUESA CONGELADA &                    BUENOS AIRES \\
#                     FRAMBUESA CONGELADA &                         TUCUMAN \\
#                                GRANADAS &                        SANTA FE \\
#                                GRANADAS &                        LA RIOJA \\
#                                GROSELLA &                       RIO NEGRO \\
#                                GROSELLA &                          CHUBUT \\
#                                  HARINA &                    BUENOS AIRES \\
#                                  HARINA &                      ENTRE RIOS \\
#                         HARINA DE COLZA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                         HARINA DE COLZA &                    BUENOS AIRES \\
#                          HARINA DE MAIZ & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                          HARINA DE MAIZ &                    BUENOS AIRES \\
#                          HARINA DE SOJA &                    BUENOS AIRES \\
#                          HARINA DE SOJA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#     JUGO CONCENTRADO CONGELADO DE LIMON &                      ENTRE RIOS \\
#     JUGO CONCENTRADO CONGELADO DE LIMON &                      CORRIENTES \\
# JUGO CONCENTRADO CONGELADO DE MANDARINA &                      ENTRE RIOS \\
# JUGO CONCENTRADO CONGELADO DE MANDARINA &                      CORRIENTES \\
#   JUGO CONCENTRADO CONGELADO DE NARANJA &                      ENTRE RIOS \\
#   JUGO CONCENTRADO CONGELADO DE NARANJA &                      CORRIENTES \\
#    JUGO CONCENTRADO CONGELADO DE POMELO &                      ENTRE RIOS \\
#    JUGO CONCENTRADO CONGELADO DE POMELO &                      CORRIENTES \\
#             JUGO CONCENTRADO DE MANZANA &                       RIO NEGRO \\
#             JUGO CONCENTRADO DE MANZANA &                         NEUQUEN \\
#                JUGO CONCENTRADO DE PERA &                       RIO NEGRO \\
#                JUGO CONCENTRADO DE PERA &                         NEUQUEN \\
#                 JUGO CONCENTRADO DE UVA &                        SAN JUAN \\
#                 JUGO CONCENTRADO DE UVA &                         MENDOZA \\
#                             LANA LAVADA &                          CHUBUT \\
#                             LANA LAVADA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                 LAVANDA &                    BUENOS AIRES \\
#                                 LAVANDA &                        SAN LUIS \\
#                                   LECHE &                       RIO NEGRO \\
#                                   LECHE &                    BUENOS AIRES \\
#                    MANZANA DESHIDRATADA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                    MANZANA DESHIDRATADA &                       RIO NEGRO \\
#                             MEDICINALES &                        SANTA FE \\
#                             MEDICINALES &                        MISIONES \\
#                                  MELAZA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                  MELAZA &                           SALTA \\
#                                   MENTA &                        SAN LUIS \\
#                                   MENTA &                    BUENOS AIRES \\
#                                 MOSTAZA &                      ENTRE RIOS \\
#                                 MOSTAZA &                    BUENOS AIRES \\
#                                   MOSTO &                        SAN JUAN \\
#                                   MOSTO &                         MENDOZA \\
#                                    NABO &                    BUENOS AIRES \\
#                                    NABO &                         CORDOBA \\
#                              NECTARINAS &                         NEUQUEN \\
#                              NECTARINAS &                       RIO NEGRO \\
#                                   PALTA &                         TUCUMAN \\
#                                   PALTA &                        SANTA FE \\
#                                    PAPA &                         CORDOBA \\
#                                    PAPA &                         MENDOZA \\
#                        PASTIZAL NATURAL &                         MENDOZA \\
#                        PASTIZAL NATURAL &                         TUCUMAN \\
#                                 PEREJIL &                    BUENOS AIRES \\
#                                 PEREJIL &                         CORDOBA \\
#                                PIMIENTO &                         CORDOBA \\
#                                PIMIENTO &                    BUENOS AIRES \\
#                                  PUERRO &                         CORDOBA \\
#                                  PUERRO &                    BUENOS AIRES \\
#                                   PULPA &                       RIO NEGRO \\
#                                   PULPA &                        SANTA FE \\
#            PULPA CONCENTRADA DE DAMASCO &                         MENDOZA \\
#            PULPA CONCENTRADA DE DAMASCO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#            PULPA CONCENTRADA DE DURAZNO &                         MENDOZA \\
#            PULPA CONCENTRADA DE DURAZNO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#            PULPA CONCENTRADA DE MANZANA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#            PULPA CONCENTRADA DE MANZANA &                         MENDOZA \\
#               PULPA CONCENTRADA DE PERA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#               PULPA CONCENTRADA DE PERA &                         MENDOZA \\
#                      PULPA DE ZANAHORIA &                         MENDOZA \\
#                      PULPA DE ZANAHORIA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                        PULPA DE ZAPALLO &                         MENDOZA \\
#                        PULPA DE ZAPALLO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                          PURE DE BATATA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                          PURE DE BATATA &                         MENDOZA \\
#                         PURE DE MANZANA &                         MENDOZA \\
#                         PURE DE MANZANA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                       PURE DE ZANAHORIA &                         MENDOZA \\
#                       PURE DE ZANAHORIA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                  QUINOA &                         TUCUMAN \\
#                                  QUINOA &                           SALTA \\
#                                RABANITO &                    BUENOS AIRES \\
#                                RABANITO &                         CORDOBA \\
#                                 REPOLLO &                        SAN JUAN \\
#                                 REPOLLO &                    BUENOS AIRES \\
#                                  RUCULA &                    BUENOS AIRES \\
#                                  RUCULA &                         CORDOBA \\
#                                  SALVIA &                    BUENOS AIRES \\
#                                  SALVIA &                         CORDOBA \\
#                                  SANDIA &                      ENTRE RIOS \\
#                                  SANDIA &                        LA RIOJA \\
#                                  STEVIA &                        MISIONES \\
#                                  STEVIA &                      ENTRE RIOS \\
#                                      TE & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                      TE &                        MISIONES \\
#                            TOPS DE LANA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                            TOPS DE LANA &                          CHUBUT \\
#                          VINO ESPUMANTE &                        SAN JUAN \\
#                          VINO ESPUMANTE &                         MENDOZA \\
#                               ZAPALLITO &                         CORDOBA \\
#                               ZAPALLITO &                    BUENOS AIRES \\
#                               ZARZAMORA &                       RIO NEGRO \\
#                               ZARZAMORA &                          CHUBUT \\
#                                ZUCCHINI &                         CORDOBA \\
#                                ZUCCHINI &                    BUENOS AIRES \\
#                        ACEITE DE CANOLA &                    BUENOS AIRES \\
#                       ACEITE DE CARTAMO &                    BUENOS AIRES \\
#                          ACEITE DE CHIA &                        LA RIOJA \\
#                         ACEITE DE LIMON &                         TUCUMAN \\
#                      ACEITE DE LIMPIEZA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                          ACEITE DE MANI &                         CORDOBA \\
#                      ACEITE DE PARAMELA &                          CHUBUT \\
#                 ACEITE DE ROSA MOSQUETA &                          CHUBUT \\
#              ACEITE ESENCIAL DE GERANIO &                       CATAMARCA \\
#           ACEITE ESENCIAL DE LEMONGRASS &                       CATAMARCA \\
#              ACEITE ESENCIAL DE OREGANO &                       CATAMARCA \\
#                                 ACEITES &                    BUENOS AIRES \\
#                        ACEITES DE COLZA &                    BUENOS AIRES \\
#                                   ACETO &                        SAN JUAN \\
#                             AGRICULTURA &                      ENTRE RIOS \\
#                                 AJEDREA &                    BUENOS AIRES \\
#                                  AJENJO &                    BUENOS AIRES \\
#                                   ALAMO &                        SAN JUAN \\
#                                ALBAHACA &                    BUENOS AIRES \\
#                               ALGARROBO &                        LA RIOJA \\
#                           ALGAS MARINAS &                          CHUBUT \\
#                     ALIMENTO BALANCEADO &                    BUENOS AIRES \\
#                                 ALPISTE &                    BUENOS AIRES \\
#                                AMARANTO &                         CORDOBA \\
#                                   ANANA &                        MISIONES \\
#                       AROMAS DE MANZANA &                         NEUQUEN \\
#                          AROMAS DE PERA &                         NEUQUEN \\
#                                AVELLANO &                          CHUBUT \\
#                                  BANANO &                         FORMOSA \\
#                              BERENJENAS &                    BUENOS AIRES \\
#                             BOYSENBERRY &                          CHUBUT \\
#                               CALENDULA &                         NEUQUEN \\
#                               CARAMELOS &                    BUENOS AIRES \\
#                                 CARTAMO & CIUDAD AUTONOMA DE BUENOS AIRES \\
#             CASCARILLA DE ROSA MOSQUETA &                          CHUBUT \\
#                                  CEDRON &                    BUENOS AIRES \\
#                               CHOCOLATE & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                   CHUFA &                    BUENOS AIRES \\
#                              CHUPETINES &                    BUENOS AIRES \\
#                              CIBOULETTE &                    BUENOS AIRES \\
#                                COLIFLOR &                    BUENOS AIRES \\
#                COMERCIALIZACION DE MANI &                         CORDOBA \\
#                              CONFITURAS &                          CHUBUT \\
#                               CORIANDRO &                      ENTRE RIOS \\
#                    CREMA FACIAL ANTIAGE & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                 CURCUMA &                    BUENOS AIRES \\
#                                  DINKEL &                    BUENOS AIRES \\
#                                  DULCES &                        SANTA FE \\
#                               ECHALOTTE &                         MENDOZA \\
#               EMULSION CORPORAL ANTIAGE & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                       ESTAMPADO DE CERA &                      ENTRE RIOS \\
#                                ESTRAGON &                    BUENOS AIRES \\
#                      EXPELLER DE CANOLA &                    BUENOS AIRES \\
#                     EXPELLER DE CARTAMO &                    BUENOS AIRES \\
#                       EXPELLER DE COLZA &                    BUENOS AIRES \\
#                EXPELLER DE COLZA CANOLA &                    BUENOS AIRES \\
#                     EXPELLER DE GIRASOL &                    BUENOS AIRES \\
#                              EXTRACCION &                        SANTA FE \\
#                      EXTRACCION DE MIEL &                      ENTRE RIOS \\
#           EXTRACTO DE ALGAS LIOFILIZADO &                          CHUBUT \\
#                    FASE OLEOSA DE LIMON &                      ENTRE RIOS \\
#                       FRUTAS TROPICALES &                         FORMOSA \\
#                       FRUTOS DEL BOSQUE &                          CHUBUT \\
#                        GEL DE ALOE VERA &                        SANTA FE \\
#                                 GERANIO &                       CATAMARCA \\
#                       GIRASOL CONFITERO &                      ENTRE RIOS \\
#                                  GRANOS & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                GUANACOS &                          CHUBUT \\
#                                  GUINDA &                          CHUBUT \\
#                                   HABAS &                    BUENOS AIRES \\
#                       HARINA DE GIRASOL & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                          HARINA DE MANI &                         CORDOBA \\
#                         HARINA DE TRIGO &                    BUENOS AIRES \\
#                          HARINA GIRASOL &                    BUENOS AIRES \\
#                             HARINA SOJA &                    BUENOS AIRES \\
#                       HARINA ZOOTECNICA &                    BUENOS AIRES \\
#                                  HINOJO &                    BUENOS AIRES \\
#                               HIPERICOM &                          CHUBUT \\
#                                  HISOPO &                    BUENOS AIRES \\
#                                    HOJA &                    BUENOS AIRES \\
#                            HOMINY GRITS &                    BUENOS AIRES \\
#                                  HUEVOS &                    BUENOS AIRES \\
#                                JENJIBRE &                    BUENOS AIRES \\
#                                  JOJOBA &                        LA RIOJA \\
#                                    KALE &                    BUENOS AIRES \\
#                                    KIWI &                    BUENOS AIRES \\
#                            LANA PEINADA &                          CHUBUT \\
#                                  LAUREL &                        LA RIOJA \\
#                                LAVANDIN &                    BUENOS AIRES \\
#                                    LIMA &                        SAN JUAN \\
#                                MANDIOCA &                        MISIONES \\
#                                   MANGO &                         FORMOSA \\
#                              MANZANILLA &                         CORDOBA \\
#                  MEGAFARDOS DE ALFALFA. &                       RIO NEGRO \\
#                                  MELISA &                    BUENOS AIRES \\
#                               MILENRAMA &                    BUENOS AIRES \\
#                         MOLIDA ENVASADA &                        MISIONES \\
#                                MORILLAS &                          CHUBUT \\
#                                PAK CHOY &                    BUENOS AIRES \\
#                       PAPILLA PARA BEBE & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                 PARTIDO &                      ENTRE RIOS \\
#                           PASTA DE MANI &                         CORDOBA \\
#                           PASTA DE PERA &                         NEUQUEN \\
#                             PASTO LIMON &                       CATAMARCA \\
#                          PATE DE TRUCHA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                  PEPINO &                         CORDOBA \\
#                              PINOT GRIS &                         MENDOZA \\
#                                PISTACHO &                        SAN JUAN \\
#    PRODUCTOS ORGANICOS DE ORIGEN ANIMAL &                    BUENOS AIRES \\
#                                  PULIDO &                      ENTRE RIOS \\
#          PULPA CONCENTRADA DE MANDARINA &                      ENTRE RIOS \\
#              PULPA CONGELADA DE NARANJA &                      ENTRE RIOS \\
#               PULPA CONGELADA DE POMELO &                      ENTRE RIOS \\
#                                   QUESO &                    BUENOS AIRES \\
#                                 QUINOTO &                        MISIONES \\
#                               RADICHETA &                    BUENOS AIRES \\
#                                    RAIZ &                        SANTA FE \\
#                         RESIDUO VEGETAL &                    BUENOS AIRES \\
#                           ROSA MOSQUETA &                          CHUBUT \\
#                                 ROSELLA &                        MISIONES \\
#                                   SAUCO &                          CHUBUT \\
#                      SEMILLA DE CEBOLLA &                         MENDOZA \\
#                       SEMILLA DE JOJOBA &                        LA RIOJA \\
#                      SEMILLA DE LECHUGA &                         MENDOZA \\
#                                SEMILLAS &                    BUENOS AIRES \\
#                       SEMILLAS DE LIMON &                      CORRIENTES \\
#                      SEMILLAS DE POMELO &                      CORRIENTES \\
#                          SEMITA DE MAIZ &                    BUENOS AIRES \\
#                         SEMOLA DE ARROZ &                      ENTRE RIOS \\
#                          SEMOLA DE MAIZ &                    BUENOS AIRES \\
#                SERUM CONTORNO DE LABIOS & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                                   SIDRA &                       RIO NEGRO \\
#                               SIN PROD. &                        MISIONES \\
#                               SMOOTHIES &                        SANTA FE \\
#                                   SYRUP &                           SALTA \\
#                           TONICO FACIAL & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                           TORTA DE SOJA & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                               TRITICALE &                      ENTRE RIOS \\
#                                  TURRON &                    BUENOS AIRES \\
#                          VACAS DE TAMBO &                    BUENOS AIRES \\
#                                VEGETAL. &                    BUENOS AIRES \\
#                                   VICIA &                         CORDOBA \\
#                                 VINAGRE &                        SAN JUAN \\
#                                   VINOS &                         MENDOZA \\
#                                  VIVERO &                         NEUQUEN \\
#                                   YERBA &                        MISIONES \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### **ii)** ¿Cuál es el CLAE2 más frecuente en establecimientos productivos? Mencionar el Código y la Descripción de dicho CLAE2

# %%
#hacemos una query que nos diga la frecuencia de los claes

query_aux = """
            SELECT clae2, COUNT(ID_ESTABLECIMIENTO) AS Frecuencia
            FROM establecimiento_productivo
            GROUP BY clae2
            ORDER BY Frecuencia DESC LIMIT 1
          """

clae_mas_frecuente = sql^ query_aux

#devuelve una tabla con cada clae2 y la cantidad de establecimientos productivos que lo tienen.
#Al estar ordenada  según frecuencia (100, 70, 20, 10, 5...), el LIMIT 1 devuelve la fila (clae2, Frecuencia) donde Frecuencia es máxima.

query = """
          SELECT r.clae2 AS Código, r.descripcion AS Descripción
          FROM rubro AS r
          WHERE r.clae2 = (
            SELECT clae_mas_frecuente.clae2
            FROM clae_mas_frecuente
          )
        """

clae2_mas_frecuente = sql^query

# %%
clae2_mas_frecuente.head()
# Out:
#    Código                                  Descripción
# 0      47  Comercio al por menor excepto autos y motos

# %%
pasar_latex(clae2_mas_frecuente)
# Out:
# \begin{tabular}{rl}
# \toprule
#  Código &                                 Descripción \\
# \midrule
#      47 & Comercio al por menor excepto autos y motos \\
# \bottomrule
# \end{tabular}
# C:\Users\luisr\AppData\Local\Temp\ipykernel_16792\4273561937.py:4: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   tabla_latex = tabla.to_latex(index=False)

# %% [markdown]
# ### **iii)** ¿Cuál es el producto más producido (que lo producen más establecimientos de operadores orgánicos)?¿Qué Provincia-Departamento los producen?

# %%
#PRIMERA PARTE DE LA PREGUNTA
#buscamos cuál es el producto más producido, es similar a lo que hicimos con el clae2

query_aux = """
              SELECT r.ID_producto AS id_producto, COUNT(r.ID_operador) AS Frecuencia
              FROM operador_produce AS r
              GROUP BY r.ID_producto
              ORDER BY Frecuencia DESC
              LIMIT 1
            """

producto_mas_producido = sql^ query_aux

#Obtenemos el id del producto que más operadores orgánicos lo tienen junto con su frecuencia

#obtenemos su nombre
query = """
                SELECT p.ID_producto AS id_producto, p.Nombre AS nombre_producto
                FROM producto_mas_producido AS p_mas_producido
                INNER JOIN productos AS p
                ON p_mas_producido.id_producto = p.ID_producto
              """

producto_mas_frecuente_organicos = sql^query

# %%
producto_mas_frecuente_organicos.head()
# Out:
#    id_producto nombre_producto
# 0           69  AZUCAR DE CAÑA

# %%
tabla_latex = producto_mas_frecuente_organicos.head().to_latex(index=False)
print(tabla_latex)
# Out:
# \begin{tabular}{rl}
# \toprule
#  id\_producto & nombre\_producto \\
# \midrule
#           69 &  AZUCAR DE CAÑA \\
# \bottomrule
# \end{tabular}
# C:\Users\luisr\AppData\Local\Temp\ipykernel_16792\3977813458.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   tabla_latex = producto_mas_frecuente_organicos.head().to_latex(index=False)

# %%
#SEGUNDA PARTE DE LA PREGUNTA
#obtenemos los id de departamentos de los operadores que lo producen, usamos el resultado anterior
query_aux = """
                SELECT DISTINCT op.ID_departamento AS id_departamento
                FROM operador_organico AS op
                INNER JOIN operador_produce AS r
                ON op.ID_operador = r.ID_operador
                WHERE r.ID_producto = 69
              """

#el DISTINCT es porque no nos interesa si hay más de un operador en un depto que lo produce, basta que haya uno

deptos_productores = sql^ query_aux

#ahora queremos saber también los nombres de esos deptos y sus provincias (id)
query_aux_2 = """
               SELECT d.ID_provincia AS id_provincia, d.ID_departamento AS id_departamento, d.Nombre AS Nombre
               FROM departamento AS d
               WHERE d.ID_departamento IN (
                SELECT deptos.id_departamento
                FROM deptos_productores AS deptos
               )
              """

provincias_deptos_productores = sql^ query_aux_2

#ahora podemos acceder a las provincias

query = """
           SELECT p.Nombre AS Provincia, d.Nombre AS Departamento
           FROM provincias_deptos_productores AS d
           INNER JOIN provincia AS p
           ON d.id_provincia = p.ID_provincia
           ORDER BY Provincia DESC, Departamento DESC
        """

lugares_produccion_organico_mas_frecuente = sql^query

# %%
lugares_produccion_organico_mas_frecuente.head()
# Out:
#   Provincia                   Departamento
# 0   TUCUMAN                      RIO CHICO
# 1   TUCUMAN                        CAPITAL
# 2     SALTA                 GENERAL GÜEMES
# 3  MISIONES                     SAN JAVIER
# 4  MISIONES  LIBERTADOR GENERAL SAN MARTIN

# %%
pasar_latex(lugares_produccion_organico_mas_frecuente)
# Out:
# \begin{tabular}{ll}
# \toprule
#                       Provincia &                    Departamento \\
# \midrule
#                         TUCUMAN &                       RIO CHICO \\
#                         TUCUMAN &                         CAPITAL \\
#                           SALTA &                  GENERAL GÜEMES \\
#                        MISIONES &                      SAN JAVIER \\
#                        MISIONES &   LIBERTADOR GENERAL SAN MARTIN \\
#                         MENDOZA &                           MAIPU \\
#                        LA RIOJA &                       CHILECITO \\
#                           JUJUY &                       SAN PEDRO \\
#                           JUJUY &                       EL CARMEN \\
#                      ENTRE RIOS &                    SAN SALVADOR \\
#                         CORDOBA &                         CAPITAL \\
# CIUDAD AUTONOMA DE BUENOS AIRES & CIUDAD AUTONOMA DE BUENOS AIRES \\
#                    BUENOS AIRES &              GENERAL PUEYRREDON \\
# \bottomrule
# \end{tabular}
# C:\Users\luisr\AppData\Local\Temp\ipykernel_16792\4273561937.py:4: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   tabla_latex = tabla.to_latex(index=False)

# %% [markdown]
# ### **iv)** ¿Existen departamentos que no presentan Operadores Orgánicos Certificados? ¿En caso de que sí, cuántos y cuáles son?

# %%
#PRIMERA PARTE DE LA PREGUNTA

#primero queremos saber todos los deptos con operadores orgánicos
query_aux = """
              SELECT DISTINCT ID_departamento
              FROM operador_organico
            """

#Ahora que los sabemos, podemos hacer restarselos (como conjuntos) a todos los deptos que tenemos
query_aux_2 = """
         SELECT d.ID_departamento AS id_departamento
         FROM departamento AS d

         EXCEPT

         SELECT DISTINCT op.ID_departamento AS id_departamento
         FROM operador_organico AS op
        """

deptos_sin_organicos = sql^ query_aux_2

#esto nos da todos los ids de aquellos departamentos donde no hay operadores orgánicos,
#podemos ver cuántos son

query = """
          SELECT COUNT(d.id_departamento) AS Cantidad_Deptos_Sin_Organicos
          FROM deptos_sin_organicos AS d
        """

cant_deptos_sin_organicos = sql^query

# %%
cant_deptos_sin_organicos.head()
# Out:
#    Cantidad_Deptos_Sin_Organicos
# 0                            308

# %%
pasar_latex(cant_deptos_sin_organicos)
# Out:
# \begin{tabular}{r}
# \toprule
#  Cantidad\_Deptos\_Sin\_Organicos \\
# \midrule
#                            308 \\
# \bottomrule
# \end{tabular}
# C:\Users\luisr\AppData\Local\Temp\ipykernel_16792\4273561937.py:4: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   tabla_latex = tabla.to_latex(index=False)

# %%
#SEGUNDA PARTE DE LA PREGUNTA

#vimos que sí existen deptos sin orgánicos, pero ya sabemos cuáles son sus id
#podemos recuperar sus nombres

query = """
          SELECT d.Nombre
          FROM departamento AS d
          WHERE d.ID_departamento IN (
              SELECT deptos_sin_organicos.id_departamento
              FROM deptos_sin_organicos
          )
        """

deptos_sin_organicos = sql^query

# %%
deptos_sin_organicos.head()
# Out:
#           Nombre
# 0  12 DE OCTUBRE
# 1     2 DE ABRIL
# 2     25 DE MAYO
# 3     25 DE MAYO
# 4     9 DE JULIO

# %%
pasar_latex(deptos_sin_organicos.head())
# Out:
# \begin{tabular}{l}
# \toprule
#        Nombre \\
# \midrule
# 12 DE OCTUBRE \\
#    2 DE ABRIL \\
#    25 DE MAYO \\
#    25 DE MAYO \\
#    9 DE JULIO \\
# \bottomrule
# \end{tabular}
# C:\Users\luisr\AppData\Local\Temp\ipykernel_16792\4273561937.py:4: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   tabla_latex = tabla.to_latex(index=False)

# %%
pasar_latex(deptos_sin_organicos)
# Out:
# C:\Users\luisr\AppData\Local\Temp\ipykernel_16792\4273561937.py:4: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   tabla_latex = tabla.to_latex(index=False)
# \begin{tabular}{l}
# \toprule
#                             Nombre \\
# \midrule
#                      12 DE OCTUBRE \\
#                         2 DE ABRIL \\
#                         25 DE MAYO \\
#                         25 DE MAYO \\
#                         9 DE JULIO \\
#                         9 DE JULIO \\
#                            AGUIRRE \\
#                            ALBERDI \\
#                    ALMIRANTE BROWN \\
#                    ALMIRANTE BROWN \\
#                            ALUMINE \\
#                             AMBATO \\
#                            ANCASTI \\
#                          ANDALGALA \\
#           ANTOFAGASTA DE LA SIERRA \\
#                          ARRECIFES \\
#                          ATAMISQUI \\
#                            ATREUCO \\
#                         AVELLANEDA \\
#                         AVELLANEDA \\
#                           AYACUCHO \\
#                           BALCARCE \\
#                              BANDA \\
#                              BELEN \\
#                           BELGRANO \\
#                           BELGRANO \\
#                        BERAZATEGUI \\
#                            BERISSO \\
#                            BERMEJO \\
#                   BERON DE ASTRADA \\
#                            BRAGADO \\
#                           BRANDSEN \\
#                          BURRUYACU \\
#                           CAINGUAS \\
#                         CANDELARIA \\
#                            CAPAYAN \\
#                            CAPITAL \\
#                            CAPITAL \\
#                            CAPITAL \\
#                  CAPITAN SARMIENTO \\
#                     CARLOS CASARES \\
#                     CARLOS TEJEDOR \\
#                        CASTELLANOS \\
#                           CASTELLI \\
#                      CASTRO BARROS \\
#                          CATAN LIL \\
#                            CATRILO \\
#                          CHACABUCO \\
#                          CHACABUCO \\
#                           CHALILEO \\
#                           CHAMICAL \\
#                         CHAPALEUFU \\
#                          CHASCOMUS \\
#                          CHICAL CO \\
#                         CHOS MALAL \\
#                              CHOYA \\
#                          COCHINOCA \\
#                        COLLON CURA \\
#                              COLON \\
#               COMANDANTE FERNANDEZ \\
#                         CONCEPCION \\
#                         CONCEPCION \\
#                             CONESA \\
#                            CONHELO \\
#                       CONSTITUCION \\
#                               COPO \\
# CORONEL DE MARINA LEONARDO ROSALES \\
#                        CORPEN AIKE \\
#                          CRUZ ALTA \\
#                             CURACO \\
#                           DAIREAUX \\
#                           DIAMANTE \\
#                            DOLORES \\
#                DR. MANUEL BELGRANO \\
#                            EL ALTO \\
#                           ELDORADO \\
#                          EMPEDRADO \\
#                           ENSENADA \\
#                            ESCOBAR \\
#                            ESQUINA \\
#                             EZEIZA \\
#                           FAMATINA \\
#                          FELICIANO \\
#                           FIGUEROA \\
#                   FLORENCIO VARELA \\
#                FLORENTINO AMEGHINO \\
#                            FORMOSA \\
#      FRAY JUSTO SANTA MARIA DE ORO \\
#                FRAY MAMERTO ESQUIU \\
#                              GARAY \\
#                     GENERAL ALVEAR \\
#          GENERAL ANGEL V. PEÑALOZA \\
#                   GENERAL ARENALES \\
#                   GENERAL BELGRANO \\
#                   GENERAL BELGRANO \\
#                   GENERAL BELGRANO \\
#                    GENERAL DONOVAN \\
#                      GENERAL GUIDO \\
#       GENERAL JUAN FACUNDO QUIROGA \\
#             GENERAL JUAN MADARIAGA \\
#                  GENERAL LA MADRID \\
#                   GENERAL LAMADRID \\
#                    GENERAL LAVALLE \\
#                      GENERAL LOPEZ \\
#                        GENERAL PAZ \\
#                  GENERAL PEDERNERA \\
#                      GENERAL PINTO \\
#                       GENERAL ROCA \\
#                  GENERAL RODRIGUEZ \\
#                 GENERAL SAN MARTIN \\
#                 GENERAL SAN MARTIN \\
#                    GENERAL TABOADA \\
#                   GENERAL VIAMONTE \\
#                   GENERAL VILLEGAS \\
#                   GOBERNADOR DUPUY \\
#                               GOYA \\
#                       GUALEGUAYCHU \\
#                            GUARANI \\
#                           GUASAYAN \\
#                           GUASAYAN \\
#                          GUATRACHE \\
#                  HIPOLITO YRIGOYEN \\
#                              HUCAL \\
#                          HUILICHES \\
#                          HUMAHUACA \\
#                         HURLINGHAM \\
#                            IGLESIA \\
#                      INDEPENDENCIA \\
#                      INDEPENDENCIA \\
#                            IRIONDO \\
#                              IRUYA \\
#            ISLAS DEL ATLANTICO SUR \\
#                   ISLAS DEL IBICUY \\
#                              ITATI \\
#                          ITUZAINGO \\
#                             JACHAL \\
#                            JIMENEZ \\
#                        JOSE C. PAZ \\
#                 JUAN FELIPE IBARRA \\
#             JUAN MARTIN PUEYRREDON \\
#                         LA CALDERA \\
#                      LA CANDELARIA \\
#                         LA CAPITAL \\
#                           LA COSTA \\
#                         LA MATANZA \\
#                             LA PAZ \\
#                             LA PAZ \\
#                            LA POMA \\
#                            LA VIÑA \\
#                              LACAR \\
#                     LAGO ARGENTINO \\
#                  LAGO BUENOS AIRES \\
#                             LAISHI \\
#                            LAPRIDA \\
#                       LAS COLONIAS \\
#                            LAVALLE \\
#                             LEALES \\
#                    LEANDRO N. ALEM \\
#                    LEANDRO N. ALEM \\
#                             LEZAMA \\
#                           LIBERTAD \\
#      LIBERTADOR GENERAL SAN MARTIN \\
#      LIBERTADOR GENERAL SAN MARTIN \\
#                       LIHUEL CALEL \\
#                      LIMAY MAHUIDA \\
#                            LOBERIA \\
#                    LOMAS DE ZAMORA \\
#                           LONCOPUE \\
#                             LORETO \\
#                          LOS ANDES \\
#                          LOS LAGOS \\
#                           LOVENTUE \\
#                          MAGDALENA \\
#                              MAIPU \\
#                              MAIPU \\
#                       MAR CHIQUITA \\
#                             MARACO \\
#                         MARCOS PAZ \\
#                            MATACOS \\
#              MAYOR LUIS J. FONTANA \\
#                          MBURUCUYA \\
#                           MERCEDES \\
#                              MERLO \\
#                              MINAS \\
#                              MINAS \\
#                              MITRE \\
#                            MOLINOS \\
#                              MONTE \\
#                      MONTE CASEROS \\
#                      MONTE HERMOSO \\
#                             MORENO \\
#                             MORENO \\
#                              MORON \\
#                            NAVARRO \\
#                           NECOCHEA \\
#                             NOGOYA \\
#                          O'HIGGINS \\
#                        OJO DE AGUA \\
#                             PACLIN \\
#                            PALPALA \\
#                 PASO DE LOS LIBRES \\
#                             PATIÑO \\
#                            PEHUAJO \\
#                         PEHUENCHES \\
#                         PELLEGRINI \\
#                         PELLEGRINI \\
#                        PICUN LEUFU \\
#                          PICUNCHES \\
#                               PILA \\
#                            PILAGAS \\
#                            PINAMAR \\
#                             PIRANE \\
#                              POCHO \\
#            PRESIDENCIA DE LA PLAZA \\
#                   PRESIDENTE PERON \\
#        PRESIDENTE ROQUE SAENZ PEÑA \\
#                             PUELEN \\
#                            PUNILLA \\
#                        PUNTA INDIO \\
#                            QUILMES \\
#                          QUITILIPI \\
#                        RAMON LISTA \\
#                             RANCUL \\
#                            REALICO \\
#                          RINCONADA \\
#                          RIO CHICO \\
#                         RIO CUARTO \\
#                        RIO SEGUNDO \\
#                          RIVADAVIA \\
#                          RIVADAVIA \\
#                          RIVADAVIA \\
#                          RIVADAVIA \\
#                             ROBLES \\
#                              ROJAS \\
#                        ROQUE PEREZ \\
#                   ROSARIO DE LERMA \\
#              ROSARIO VERA PEÑALOZA \\
#                            SALADAS \\
#                          SALADILLO \\
#                           SALAVINA \\
#                         SALLIQUELO \\
#                              SALTO \\
#                        SAN ALBERTO \\
#                SAN ANDRES DE GILES \\
#                        SAN ANTONIO \\
#                        SAN ANTONIO \\
#             SAN BLAS DE LOS SAUCES \\
#                       SAN CAYETANO \\
#                          SAN COSME \\
#                      SAN CRISTOBAL \\
#                       SAN FERNANDO \\
#                       SAN FERNANDO \\
#                          SAN JUSTO \\
#                          SAN JUSTO \\
#                        SAN LORENZO \\
#                SAN LUIS DEL PALMAR \\
#                         SAN MARTIN \\
#                         SAN MARTIN \\
#                         SAN MIGUEL \\
#                         SAN MIGUEL \\
#                          SAN PEDRO \\
#                          SAN ROQUE \\
#                        SAN VICENTE \\
#                          SANAGASTA \\
#                     SANTA CATALINA \\
#                     SANTA VICTORIA \\
#                         SANTO TOME \\
#                    SARGENTO CABRAL \\
#                          SARMIENTO \\
#                          SARMIENTO \\
#                              SAUCE \\
#                           SILIPICA \\
#                             SIMOCA \\
#                         SOBREMONTE \\
#                           SUIPACHA \\
#                            SUSQUES \\
#                     TAFI DEL VALLE \\
#                         TAFI VIEJO \\
#                               TALA \\
#                           TAPALQUE \\
#                           TAPENAGA \\
#                             TELSEN \\
#                     TERCERO ARRIBA \\
#                              TIGRE \\
#                            TILCARA \\
#                               TOAY \\
#                           TORDILLO \\
#                          TORNQUIST \\
#                            TOTORAL \\
#                            TRANCAS \\
#                             TRENEL \\
#                    TRENQUE LAUQUEN \\
#                    TRES DE FEBRERO \\
#                         TRES LOMAS \\
#                            TULUMBA \\
#                            TUMBAYA \\
#                              ULLUM \\
#                              UNION \\
#                            USHUAIA \\
#                           VALCHETA \\
#                       VALLE FERTIL \\
#                       VALLE GRANDE \\
#                               VERA \\
#                      VICENTE LOPEZ \\
#                       VILLA GESELL \\
#                           VINCHINA \\
#                               YAVI \\
#                             ZAPALA \\
#                              ZONDA \\
#                            ÑORQUIN \\
#                          ÑORQUINCO \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### **v)** ¿Cuál es la tasa promedio de participación de mujeres en cada provincia?¿Cuál es su desvío? En cada caso, mencionar si es mayor o menor al promedio de todo el país

# %%
#PRIMERA y SEGUNDA PARTE DE LA PREGUNTA

#asociamos a cada establecimiento con su provincia
query_aux = """
              SELECT d.ID_provincia AS id_provincia, e.proporcion_mujeres
              FROM establecimiento_productivo AS e
              INNER JOIN departamento AS d
              ON e.ID_departamento = d.ID_departamento
            """

establecimiento_provincia_temp = sql^query_aux

#ahora lo asociamos con el nombre de la provincia
query_aux_2 = """
               SELECT p.ID_provincia AS id_provincia, p.Nombre AS Provincia, est_prov.proporcion_mujeres
               FROM establecimiento_provincia_temp AS est_prov
               INNER JOIN provincia AS p
               ON p.ID_provincia = est_prov.id_provincia
              """

#ahora podemos obtener los promedios por provincia

establecimiento_provincia = sql^ query_aux_2

query = """
          SELECT p.Provincia,
          MEAN(p.proporcion_mujeres) AS Promedio,
          STDDEV(p.proporcion_mujeres) AS Desvío_Estándar
          FROM establecimiento_provincia AS p
          GROUP BY p.Provincia
        """

promedios_desvios_por_provincia = sql^query

# %%
promedios_desvios_por_provincia.head(24)
# Out:
#                           Provincia  Promedio  Desvío_Estándar
# 0                           MENDOZA  0.293746         0.381336
# 1                          MISIONES  0.285687         0.382625
# 2                           NEUQUEN  0.392237         0.409228
# 3                      BUENOS AIRES  0.366185         0.411236
# 4                         RIO NEGRO  0.386776         0.412597
# 5                            CHUBUT  0.393871         0.416513
# 6   CIUDAD AUTONOMA DE BUENOS AIRES  0.369359         0.402625
# 7                        ENTRE RIOS  0.317706         0.407682
# 8                           FORMOSA  0.295129         0.387735
# 9                             JUJUY  0.329559         0.390035
# 10                         LA PAMPA  0.340086         0.420482
# 11                         LA RIOJA  0.328645         0.391269
# 12                         SAN LUIS  0.352463         0.406671
# 13                       SANTA CRUZ  0.404974         0.411509
# 14                         SANTA FE  0.338563         0.409912
# 15              SANTIAGO DEL ESTERO  0.310159         0.392230
# 16                        CATAMARCA  0.328172         0.400906
# 17                          TUCUMAN  0.310114         0.389906
# 18                 TIERRA DEL FUEGO  0.380751         0.406489
# 19                            SALTA  0.329520         0.389074
# 20                         SAN JUAN  0.289829         0.386164
# 21                            CHACO  0.266632         0.378535
# 22                          CORDOBA  0.345103         0.411314
# 23                       CORRIENTES  0.261424         0.373256

# %%
#TERCERA PARTE DE LA PREGUNTA

#hay que obtener los valores para el promedio y desvío a nivel nacional

query_aux = """
              SELECT MEAN(e.proporcion_mujeres) AS Promedio_Nacional,
              STDDEV(e.proporcion_mujeres) AS Desvío_Estándar_Nacional
              FROM establecimiento_productivo AS e
            """

temp_datos_nivel_nacional = sql^query_aux
temp_datos_nivel_nacional.head()
# Out:
#    Promedio_Nacional  Desvío_Estándar_Nacional
# 0           0.350244                   0.40581

# %%
pasar_latex(temp_datos_nivel_nacional)
# Out:
# \begin{tabular}{rr}
# \toprule
#  Promedio\_Nacional &  Desvío\_Estándar\_Nacional \\
# \midrule
#           0.350244 &                   0.40581 \\
# \bottomrule
# \end{tabular}
# C:\Users\luisr\AppData\Local\Temp\ipykernel_16792\4273561937.py:4: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   tabla_latex = tabla.to_latex(index=False)

# %%
#ya podemos decidir cuándo es mayor o menor a los datos nacionales

query = """
          SELECT p.Provincia,
          MEAN(p.proporcion_mujeres) AS Promedio,
          STDDEV(p.proporcion_mujeres) AS Desvío_Estándar,
          CASE WHEN Promedio >= (SELECT MEAN(e.proporcion_mujeres) FROM establecimiento_productivo AS e) THEN 'Mayor' ELSE 'Menor' END AS Respecto_Promedio_Nacional,
          CASE WHEN Desvío_Estándar > (SELECT STDDEV(e.proporcion_mujeres) FROM establecimiento_productivo AS e) THEN 'Mayor' ELSE 'Menor' END AS Respecto_Desvío_Nacional
          FROM establecimiento_provincia AS p
          GROUP BY p.Provincia
          ORDER BY p.provincia
        """

promedios_desvios_por_provincia_comparados = sql^query

# %%
promedios_desvios_por_provincia_comparados.head(24)
# Out:
#                           Provincia  Promedio  Desvío_Estándar  \
# 0                      BUENOS AIRES  0.366185         0.411236
# 1                         CATAMARCA  0.328172         0.400906
# 2                             CHACO  0.266632         0.378535
# 3                            CHUBUT  0.393871         0.416513
# 4   CIUDAD AUTONOMA DE BUENOS AIRES  0.369359         0.402625
# 5                           CORDOBA  0.345103         0.411314
# 6                        CORRIENTES  0.261424         0.373256
# 7                        ENTRE RIOS  0.317706         0.407682
# 8                           FORMOSA  0.295129         0.387735
# 9                             JUJUY  0.329559         0.390035
# 10                         LA PAMPA  0.340086         0.420482
# 11                         LA RIOJA  0.328645         0.391269
# 12                          MENDOZA  0.293746         0.381336
# 13                         MISIONES  0.285687         0.382625
# 14                          NEUQUEN  0.392237         0.409228
# 15                        RIO NEGRO  0.386776         0.412597
# 16                            SALTA  0.329520         0.389074
# 17                         SAN JUAN  0.289829         0.386164
# 18                         SAN LUIS  0.352463         0.406671
# 19                       SANTA CRUZ  0.404974         0.411509
# 20                         SANTA FE  0.338563         0.409912
# 21              SANTIAGO DEL ESTERO  0.310159         0.392230
# 22                 TIERRA DEL FUEGO  0.380751         0.406489
# 23                          TUCUMAN  0.310114         0.389906
#
#    Respecto_Promedio_Nacional Respecto_Desvío_Nacional
# 0                       Mayor                    Mayor
# 1                       Menor                    Menor
# 2                       Menor                    Menor
# 3                       Mayor                    Mayor
# 4                       Mayor                    Menor
# 5                       Menor                    Mayor
# 6                       Menor                    Menor
# 7                       Menor                    Mayor
# 8                       Menor                    Menor
# 9                       Menor                    Menor
# 10                      Menor                    Mayor
# 11                      Menor                    Menor
# 12                      Menor                    Menor
# 13                      Menor                    Menor
# 14                      Mayor                    Mayor
# 15                      Mayor                    Mayor
# 16                      Menor                    Menor
# 17                      Menor                    Menor
# 18                      Mayor                    Mayor
# 19                      Mayor                    Mayor
# 20                      Menor                    Mayor
# 21                      Menor                    Menor
# 22                      Mayor                    Mayor
# 23                      Menor                    Menor

# %%
pasar_latex(promedios_desvios_por_provincia_comparados.head(3))
# Out:
# C:\Users\luisr\AppData\Local\Temp\ipykernel_16792\4273561937.py:4: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   tabla_latex = tabla.to_latex(index=False)
# \begin{tabular}{lrrll}
# \toprule
#    Provincia &  Promedio &  Desvío\_Estándar & Respecto\_Promedio\_Nacional & Respecto\_Desvío\_Nacional \\
# \midrule
# BUENOS AIRES &  0.366185 &         0.411236 &                      Mayor &                    Mayor \\
#    CATAMARCA &  0.328172 &         0.400906 &                      Menor &                    Menor \\
#        CHACO &  0.266632 &         0.378535 &                      Menor &                    Menor \\
# \bottomrule
# \end{tabular}

# %%
pasar_latex(promedios_desvios_por_provincia_comparados)
# Out:
# \begin{tabular}{lrrll}
# \toprule
#                       Provincia &  Promedio &  Desvío\_Estándar & Respecto\_Promedio\_Nacional & Respecto\_Desvío\_Nacional \\
# \midrule
#                    BUENOS AIRES &  0.366185 &         0.411236 &                      Mayor &                    Mayor \\
#                       CATAMARCA &  0.328172 &         0.400906 &                      Menor &                    Menor \\
#                           CHACO &  0.266632 &         0.378535 &                      Menor &                    Menor \\
#                          CHUBUT &  0.393871 &         0.416513 &                      Mayor &                    Mayor \\
# CIUDAD AUTONOMA DE BUENOS AIRES &  0.369359 &         0.402625 &                      Mayor &                    Menor \\
#                         CORDOBA &  0.345103 &         0.411314 &                      Menor &                    Mayor \\
#                      CORRIENTES &  0.261424 &         0.373256 &                      Menor &                    Menor \\
#                      ENTRE RIOS &  0.317706 &         0.407682 &                      Menor &                    Mayor \\
#                         FORMOSA &  0.295129 &         0.387735 &                      Menor &                    Menor \\
#                           JUJUY &  0.329559 &         0.390035 &                      Menor &                    Menor \\
#                        LA PAMPA &  0.340086 &         0.420482 &                      Menor &                    Mayor \\
#                        LA RIOJA &  0.328645 &         0.391269 &                      Menor &                    Menor \\
#                         MENDOZA &  0.293746 &         0.381336 &                      Menor &                    Menor \\
#                        MISIONES &  0.285687 &         0.382625 &                      Menor &                    Menor \\
#                         NEUQUEN &  0.392237 &         0.409228 &                      Mayor &                    Mayor \\
#                       RIO NEGRO &  0.386776 &         0.412597 &                      Mayor &                    Mayor \\
#                           SALTA &  0.329520 &         0.389074 &                      Menor &                    Menor \\
#                        SAN JUAN &  0.289829 &         0.386164 &                      Menor &                    Menor \\
#                        SAN LUIS &  0.352463 &         0.406671 &                      Mayor &                    Mayor \\
#                      SANTA CRUZ &  0.404974 &         0.411509 &                      Mayor &                    Mayor \\
#                        SANTA FE &  0.338563 &         0.409912 &                      Menor &                    Mayor \\
#             SANTIAGO DEL ESTERO &  0.310159 &         0.392230 &                      Menor &                    Menor \\
#                TIERRA DEL FUEGO &  0.380751 &         0.406489 &                      Mayor &                    Mayor \\
#                         TUCUMAN &  0.310114 &         0.389906 &                      Menor &                    Menor \\
# \bottomrule
# \end{tabular}
# C:\Users\luisr\AppData\Local\Temp\ipykernel_16792\4273561937.py:4: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   tabla_latex = tabla.to_latex(index=False)

# %% [markdown]
# ### **vi)** Mostrar por cada provincia-departamento cuántos establecimientos productivos y cuántos emprendimientos orgánicos posee

# %%
#Obtenemos la cantidad de establecimientos productivos por departamento

query_aux = """
              SELECT e.ID_departamento AS id_departamento, COUNT(e.ID_establecimiento) AS establecimientos
              FROM establecimiento_productivo AS e
              GROUP BY e.ID_departamento
              ORDER BY establecimientos DESC
            """

cant_est_por_depto_temp = sql^ query_aux

#A los deptos sin establecimientos debemos ponerlos en cero

query_aux_2 = """
               SELECT d.ID_provincia AS id_provincia,
               d.ID_departamento AS id_departamento,
               d.Nombre AS Nombre,
               CASE WHEN d2.establecimientos IS NULL THEN 0 else d2.establecimientos END AS establecimientos
               FROM departamento AS d
               LEFT OUTER JOIN cant_est_por_depto_temp AS d2
               ON d.ID_departamento = d2.id_departamento
              """

cant_est_por_depto = sql^ query_aux_2
#hacemos exactamento lo mismo pero con operadores organicos

#obtenemos los organicos por departamento
query_aux_3 = """
              SELECT op.ID_departamento AS id_departamento, COUNT(op.ID_operador) AS operadores_organicos
              FROM operador_organico AS op
              GROUP BY op.ID_departamento
              ORDER BY operadores_organicos DESC
            """

cant_org_por_depto_temp = sql^ query_aux_3

#hacemos el left outer join con los deptos como antes

query_aux_4 = """
               SELECT d.ID_provincia AS id_provincia,
               d.ID_departamento AS id_departamento,
               d.Nombre AS Nombre,
               CASE WHEN d2.operadores_organicos IS NULL THEN 0 else d2.operadores_organicos END AS operadores_organicos
               FROM departamento AS d
               LEFT OUTER JOIN cant_org_por_depto_temp AS d2
               ON d.ID_departamento = d2.id_departamento
              """


cant_org_por_depto = sql^ query_aux_4
#ya está, ahora podemos hacer un inner join y juntar las dos tablas

query_aux_5 = """
          SELECT
          d1.id_provincia,
          d1.Nombre AS Departamento,
          d1.establecimientos AS Establecimientos_Productivos,
          d2.operadores_organicos As Operadores_Organicos
          FROM cant_est_por_depto AS d1
          INNER JOIN cant_org_por_depto AS d2
          ON d1.id_departamento = d2.id_departamento
        """

cant_productores_por_depto = sql^ query_aux_5

#Sólo queda relacionar cada depto con su provincia

query = """
          SELECT p.Nombre AS Provincia,
          d.Departamento,
          d.Establecimientos_Productivos,
          d.Operadores_Organicos
          FROM cant_productores_por_depto AS d
          INNER JOIN provincia AS p
          ON p.ID_provincia = d.id_provincia
          ORDER BY p.Nombre, d.Establecimientos_Productivos DESC, d.Departamento
        """

distribucion_establecimientos_y_organicos_por_departamento = sql^query

# %%
distribucion_establecimientos_y_organicos_por_departamento.head()
# Out:
#       Provincia        Departamento  Establecimientos_Productivos  \
# 0  BUENOS AIRES  GENERAL PUEYRREDON                         14003
# 1  BUENOS AIRES          LA MATANZA                         12599
# 2  BUENOS AIRES       VICENTE LOPEZ                          8290
# 3  BUENOS AIRES          SAN ISIDRO                          8221
# 4  BUENOS AIRES        BAHIA BLANCA                          7475
#
#    Operadores_Organicos
# 0                     7
# 1                     0
# 2                     0
# 3                     1
# 4                     2

# %%
pasar_latex(distribucion_establecimientos_y_organicos_por_departamento.head(6))
# Out:
# \begin{tabular}{llrr}
# \toprule
#    Provincia &       Departamento &  Establecimientos\_Productivos &  Operadores\_Organicos \\
# \midrule
# BUENOS AIRES & GENERAL PUEYRREDON &                         14003 &                     7 \\
# BUENOS AIRES &         LA MATANZA &                         12599 &                     0 \\
# BUENOS AIRES &      VICENTE LOPEZ &                          8290 &                     0 \\
# BUENOS AIRES &         SAN ISIDRO &                          8221 &                     1 \\
# BUENOS AIRES &       BAHIA BLANCA &                          7475 &                     2 \\
# BUENOS AIRES &           LA PLATA &                          7323 &                     5 \\
# \bottomrule
# \end{tabular}
# C:\Users\luisr\AppData\Local\Temp\ipykernel_16792\4273561937.py:4: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   tabla_latex = tabla.to_latex(index=False)

# %%
pasar_latex(distribucion_establecimientos_y_organicos_por_departamento)
# Out:
# \begin{tabular}{llrr}
# \toprule
#                       Provincia &                       Departamento &  Establecimientos\_Productivos &  Operadores\_Organicos \\
# \midrule
#                    BUENOS AIRES &                 GENERAL PUEYRREDON &                         14003 &                     7 \\
#                    BUENOS AIRES &                         LA MATANZA &                         12599 &                     0 \\
#                    BUENOS AIRES &                      VICENTE LOPEZ &                          8290 &                     0 \\
#                    BUENOS AIRES &                         SAN ISIDRO &                          8221 &                     1 \\
#                    BUENOS AIRES &                       BAHIA BLANCA &                          7475 &                     2 \\
#                    BUENOS AIRES &                           LA PLATA &                          7323 &                     5 \\
#                    BUENOS AIRES &                 GENERAL SAN MARTIN &                          7218 &                     0 \\
#                    BUENOS AIRES &                    LOMAS DE ZAMORA &                          6611 &                     0 \\
#                    BUENOS AIRES &                            QUILMES &                          6336 &                     0 \\
#                    BUENOS AIRES &                              LANUS &                          6154 &                     3 \\
#                    BUENOS AIRES &                    TRES DE FEBRERO &                          5875 &                     0 \\
#                    BUENOS AIRES &                         AVELLANEDA &                          5696 &                     0 \\
#                    BUENOS AIRES &                              MORON &                          5588 &                     0 \\
#                    BUENOS AIRES &                              TIGRE &                          5544 &                     0 \\
#                    BUENOS AIRES &                              PILAR &                          4585 &                     1 \\
#                    BUENOS AIRES &                    ALMIRANTE BROWN &                          3900 &                     0 \\
#                    BUENOS AIRES &                             TANDIL &                          3862 &                     3 \\
#                    BUENOS AIRES &                         SAN MIGUEL &                          3037 &                     0 \\
#                    BUENOS AIRES &                             MORENO &                          2939 &                     0 \\
#                    BUENOS AIRES &                 ESTEBAN ECHEVERRIA &                          2650 &                     2 \\
#                    BUENOS AIRES &                            ESCOBAR &                          2570 &                     0 \\
#                    BUENOS AIRES &                              MERLO &                          2537 &                     0 \\
#                    BUENOS AIRES &                MALVINAS ARGENTINAS &                          2510 &                     2 \\
#                    BUENOS AIRES &                        BERAZATEGUI &                          2439 &                     0 \\
#                    BUENOS AIRES &                          OLAVARRIA &                          2410 &                     1 \\
#                    BUENOS AIRES &                       SAN FERNANDO &                          2376 &                     0 \\
#                    BUENOS AIRES &                          PERGAMINO &                          2310 &                     1 \\
#                    BUENOS AIRES &                              JUNIN &                          2239 &                     1 \\
#                    BUENOS AIRES &                        SAN NICOLAS &                          2237 &                     1 \\
#                    BUENOS AIRES &                           NECOCHEA &                          2091 &                     0 \\
#                    BUENOS AIRES &                          ITUZAINGO &                          1933 &                     1 \\
#                    BUENOS AIRES &                   FLORENCIO VARELA &                          1923 &                     0 \\
#                    BUENOS AIRES &                              LUJAN &                          1913 &                     4 \\
#                    BUENOS AIRES &                             ZARATE &                          1757 &                     1 \\
#                    BUENOS AIRES &                           LA COSTA &                          1676 &                     0 \\
#                    BUENOS AIRES &                         HURLINGHAM &                          1649 &                     0 \\
#                    BUENOS AIRES &                               AZUL &                          1607 &                    10 \\
#                    BUENOS AIRES &                            CAMPANA &                          1593 &                     1 \\
#                    BUENOS AIRES &                             EZEIZA &                          1569 &                     0 \\
#                    BUENOS AIRES &                       TRES ARROYOS &                          1567 &                     4 \\
#                    BUENOS AIRES &                          CHIVILCOY &                          1385 &                     3 \\
#                    BUENOS AIRES &                  GENERAL RODRIGUEZ &                          1347 &                     0 \\
#                    BUENOS AIRES &                    TRENQUE LAUQUEN &                          1340 &                     0 \\
#                    BUENOS AIRES &                            PINAMAR &                          1246 &                     0 \\
#                    BUENOS AIRES &                        JOSE C. PAZ &                          1201 &                     0 \\
#                    BUENOS AIRES &                          SAN PEDRO &                          1132 &                     6 \\
#                    BUENOS AIRES &                       VILLA GESELL &                          1123 &                     0 \\
#                    BUENOS AIRES &                            LINCOLN &                          1096 &                     1 \\
#                    BUENOS AIRES &                           BALCARCE &                          1094 &                     0 \\
#                    BUENOS AIRES &                          CHACABUCO &                          1094 &                     4 \\
#                    BUENOS AIRES &                         9 DE JULIO &                          1078 &                     1 \\
#                    BUENOS AIRES &                           MERCEDES &                          1075 &                     3 \\
#                    BUENOS AIRES &                     CORONEL SUAREZ &                          1014 &                     2 \\
#                    BUENOS AIRES &                           CAÑUELAS &                           949 &                     1 \\
#                    BUENOS AIRES &                   GENERAL VILLEGAS &                           948 &                     0 \\
#                    BUENOS AIRES &                            PEHUAJO &                           910 &                     0 \\
#                    BUENOS AIRES &                   GENERAL ALVARADO &                           901 &                     1 \\
#                    BUENOS AIRES &                            BOLIVAR &                           897 &                     6 \\
#                    BUENOS AIRES &                          CHASCOMUS &                           850 &                     0 \\
#                    BUENOS AIRES &                            BRAGADO &                           841 &                     0 \\
#                    BUENOS AIRES &                              LOBOS &                           785 &                     1 \\
#                    BUENOS AIRES &                         25 DE MAYO &                           767 &                     2 \\
#                    BUENOS AIRES &                              SALTO &                           738 &                     0 \\
#                    BUENOS AIRES &                          SALADILLO &                           698 &                     0 \\
#                    BUENOS AIRES &                           BARADERO &                           690 &                     9 \\
#                    BUENOS AIRES &                            RAMALLO &                           664 &                     1 \\
#                    BUENOS AIRES &                            BERISSO &                           659 &                     0 \\
#                    BUENOS AIRES & CORONEL DE MARINA LEONARDO ROSALES &                           610 &                     0 \\
#                    BUENOS AIRES &                              ROJAS &                           609 &                     0 \\
#                    BUENOS AIRES &                           ENSENADA &                           603 &                     0 \\
#                    BUENOS AIRES &                          VILLARINO &                           602 &                     4 \\
#                    BUENOS AIRES &                           AYACUCHO &                           594 &                     0 \\
#                    BUENOS AIRES &                        SAN VICENTE &                           585 &                     0 \\
#                    BUENOS AIRES &                          ARRECIFES &                           578 &                     0 \\
#                    BUENOS AIRES &                   CORONEL PRINGLES &                           563 &                     1 \\
#                    BUENOS AIRES &                           SAAVEDRA &                           557 &                     1 \\
#                    BUENOS AIRES &                     CARLOS CASARES &                           552 &                     0 \\
#                    BUENOS AIRES &                          RIVADAVIA &                           551 &                     0 \\
#                    BUENOS AIRES &               SAN ANTONIO DE ARECO &                           546 &                     1 \\
#                    BUENOS AIRES &                SAN ANDRES DE GILES &                           521 &                     0 \\
#                    BUENOS AIRES &              EXALTACION DE LA CRUZ &                           520 &                     3 \\
#                    BUENOS AIRES &                           BRANDSEN &                           516 &                     0 \\
#                    BUENOS AIRES &                      BENITO JUAREZ &                           510 &                     3 \\
#                    BUENOS AIRES &                            LOBERIA &                           505 &                     0 \\
#                    BUENOS AIRES &                          PATAGONES &                           485 &                    24 \\
#                    BUENOS AIRES &                            DOLORES &                           483 &                     0 \\
#                    BUENOS AIRES &                         MARCOS PAZ &                           481 &                     0 \\
#                    BUENOS AIRES &                              COLON &                           470 &                     1 \\
#                    BUENOS AIRES &                              MONTE &                           460 &                     0 \\
#                    BUENOS AIRES &                         LAS FLORES &                           458 &                     6 \\
#                    BUENOS AIRES &             GENERAL JUAN MADARIAGA &                           455 &                     0 \\
#                    BUENOS AIRES &                    LEANDRO N. ALEM &                           448 &                     0 \\
#                    BUENOS AIRES &                       MAR CHIQUITA &                           448 &                     0 \\
#                    BUENOS AIRES &                           DAIREAUX &                           442 &                     0 \\
#                    BUENOS AIRES &                      ADOLFO ALSINA &                           432 &                     1 \\
#                    BUENOS AIRES &                   GENERAL ARENALES &                           415 &                     0 \\
#                    BUENOS AIRES &                               PUAN &                           409 &                     5 \\
#                    BUENOS AIRES &                    CORONEL DORREGO &                           405 &                     3 \\
#                    BUENOS AIRES &                   GENERAL BELGRANO &                           400 &                     0 \\
#                    BUENOS AIRES &                              RAUCH &                           394 &                     3 \\
#                    BUENOS AIRES &                          TORNQUIST &                           392 &                     0 \\
#                    BUENOS AIRES &                    CARMEN DE ARECO &                           373 &                     7 \\
#                    BUENOS AIRES &                   GENERAL VIAMONTE &                           353 &                     0 \\
#                    BUENOS AIRES &                   PRESIDENTE PERON &                           338 &                     0 \\
#                    BUENOS AIRES &                  CAPITAN SARMIENTO &                           332 &                     0 \\
#                    BUENOS AIRES &                            NAVARRO &                           330 &                     0 \\
#                    BUENOS AIRES &                          MAGDALENA &                           318 &                     0 \\
#                    BUENOS AIRES &                            GUAMINI &                           317 &                     1 \\
#                    BUENOS AIRES &             ADOLFO GONZALES CHAVES &                           313 &                     1 \\
#                    BUENOS AIRES &                        ROQUE PEREZ &                           311 &                     0 \\
#                    BUENOS AIRES &                  GENERAL LA MADRID &                           308 &                     0 \\
#                    BUENOS AIRES &                      MONTE HERMOSO &                           260 &                     0 \\
#                    BUENOS AIRES &                      GENERAL PINTO &                           259 &                     0 \\
#                    BUENOS AIRES &                            LAPRIDA &                           249 &                     0 \\
#                    BUENOS AIRES &                     CARLOS TEJEDOR &                           239 &                     0 \\
#                    BUENOS AIRES &                            ALBERTI &                           238 &                     8 \\
#                    BUENOS AIRES &                         SALLIQUELO &                           235 &                     0 \\
#                    BUENOS AIRES &                  HIPOLITO YRIGOYEN &                           230 &                     0 \\
#                    BUENOS AIRES &                FLORENTINO AMEGHINO &                           229 &                     0 \\
#                    BUENOS AIRES &                           TAPALQUE &                           224 &                     0 \\
#                    BUENOS AIRES &                  GENERAL LAS HERAS &                           223 &                     2 \\
#                    BUENOS AIRES &                        GENERAL PAZ &                           220 &                     1 \\
#                    BUENOS AIRES &                              MAIPU &                           213 &                     0 \\
#                    BUENOS AIRES &                             LEZAMA &                           212 &                     0 \\
#                    BUENOS AIRES &                       SAN CAYETANO &                           202 &                     0 \\
#                    BUENOS AIRES &                           SUIPACHA &                           197 &                     0 \\
#                    BUENOS AIRES &                           CASTELLI &                           194 &                     0 \\
#                    BUENOS AIRES &                         TRES LOMAS &                           184 &                     0 \\
#                    BUENOS AIRES &                     GENERAL ALVEAR &                           182 &                     0 \\
#                    BUENOS AIRES &                         PELLEGRINI &                           178 &                     0 \\
#                    BUENOS AIRES &                        PUNTA INDIO &                           158 &                     0 \\
#                    BUENOS AIRES &                    GENERAL LAVALLE &                           136 &                     0 \\
#                    BUENOS AIRES &                      GENERAL GUIDO &                            95 &                     0 \\
#                    BUENOS AIRES &                               PILA &                            43 &                     0 \\
#                    BUENOS AIRES &                           TORDILLO &                            35 &                     0 \\
#                       CATAMARCA &                            CAPITAL &                          2295 &                     1 \\
#                       CATAMARCA &                              BELEN &                           202 &                     0 \\
#                       CATAMARCA &                        SANTA MARIA &                           196 &                     1 \\
#                       CATAMARCA &                          ANDALGALA &                           166 &                     0 \\
#                       CATAMARCA &                          TINOGASTA &                           133 &                     4 \\
#                       CATAMARCA &                             LA PAZ &                           107 &                     0 \\
#                       CATAMARCA &                             LA PAZ &                           107 &                     0 \\
#                       CATAMARCA &                        VALLE VIEJO &                           106 &                     2 \\
#                       CATAMARCA &                         SANTA ROSA &                            89 &                     1 \\
#                       CATAMARCA &                              POMAN &                            87 &                     4 \\
#                       CATAMARCA &                FRAY MAMERTO ESQUIU &                            84 &                     0 \\
#                       CATAMARCA &                            CAPAYAN &                            46 &                     0 \\
#                       CATAMARCA &                             AMBATO &                            24 &                     0 \\
#                       CATAMARCA &           ANTOFAGASTA DE LA SIERRA &                            24 &                     0 \\
#                       CATAMARCA &                           GUASAYAN &                            23 &                     0 \\
#                       CATAMARCA &                           GUASAYAN &                            23 &                     0 \\
#                       CATAMARCA &                            EL ALTO &                            18 &                     0 \\
#                       CATAMARCA &                             PACLIN &                            17 &                     0 \\
#                       CATAMARCA &                            ANCASTI &                            15 &                     0 \\
#                           CHACO &                       SAN FERNANDO &                          4968 &                     0 \\
#                           CHACO &               COMANDANTE FERNANDEZ &                          1085 &                     0 \\
#                           CHACO &              MAYOR LUIS J. FONTANA &                           654 &                     0 \\
#                           CHACO &                          CHACABUCO &                           598 &                     0 \\
#                           CHACO &                     GENERAL GÜEMES &                           323 &                     8 \\
#                           CHACO &      LIBERTADOR GENERAL SAN MARTIN &                           307 &                     0 \\
#                           CHACO &                      INDEPENDENCIA &                           302 &                     0 \\
#                           CHACO &                    ALMIRANTE BROWN &                           293 &                     0 \\
#                           CHACO &                         9 DE JULIO &                           266 &                     0 \\
#                           CHACO &                          QUITILIPI &                           223 &                     0 \\
#                           CHACO &                         25 DE MAYO &                           219 &                     0 \\
#                           CHACO &                              MAIPU &                           209 &                     0 \\
#                           CHACO &                      12 DE OCTUBRE &                           156 &                     0 \\
#                           CHACO &            PRESIDENCIA DE LA PLAZA &                           153 &                     0 \\
#                           CHACO &                          O'HIGGINS &                           136 &                     0 \\
#                           CHACO &                         2 DE ABRIL &                           135 &                     0 \\
#                           CHACO &                           LIBERTAD &                           111 &                     0 \\
#                           CHACO &                            BERMEJO &                           108 &                     1 \\
#                           CHACO &                   GENERAL BELGRANO &                            91 &                     0 \\
#                           CHACO &                        SAN LORENZO &                            83 &                     0 \\
#                           CHACO &                         1º DE MAYO &                            77 &                     1 \\
#                           CHACO &                    SARGENTO CABRAL &                            60 &                     0 \\
#                           CHACO &                           TAPENAGA &                            50 &                     0 \\
#                           CHACO &      FRAY JUSTO SANTA MARIA DE ORO &                            42 &                     0 \\
#                           CHACO &                    GENERAL DONOVAN &                             5 &                     0 \\
#                          CHUBUT &                          ESCALANTE &                          4005 &                     4 \\
#                          CHUBUT &                             RAWSON &                          2457 &                     7 \\
#                          CHUBUT &                             BIEDMA &                          1993 &                     1 \\
#                          CHUBUT &                             BIEDMA &                          1993 &                     1 \\
#                          CHUBUT &                          FUTALEUFU &                           855 &                     3 \\
#                          CHUBUT &                           CUSHAMEN &                           225 &                    12 \\
#                          CHUBUT &                             GAIMAN &                           209 &                     4 \\
#                          CHUBUT &                          SARMIENTO &                           194 &                     0 \\
#                          CHUBUT &                         TEHUELCHES &                           107 &                     2 \\
#                          CHUBUT &                        RIO SENGUER &                           106 &                     7 \\
#                          CHUBUT &                     PASO DE INDIOS &                            29 &                     1 \\
#                          CHUBUT &                FLORENTINO AMEGHINO &                            25 &                     2 \\
#                          CHUBUT &                          LANGUIÑEO &                            19 &                     1 \\
#                          CHUBUT &                           MARTIRES &                            17 &                     1 \\
#                          CHUBUT &                             GASTRE &                            12 &                     2 \\
#                          CHUBUT &                             TELSEN &                            12 &                     0 \\
# CIUDAD AUTONOMA DE BUENOS AIRES &    CIUDAD AUTONOMA DE BUENOS AIRES &                        157563 &                    44 \\
#                         CORDOBA &                            CAPITAL &                         24118 &                     5 \\
#                         CORDOBA &                         RIO CUARTO &                          6184 &                     0 \\
#                         CORDOBA &                          SAN JUSTO &                          5059 &                     0 \\
#                         CORDOBA &                 GENERAL SAN MARTIN &                          3515 &                    16 \\
#                         CORDOBA &                            PUNILLA &                          3506 &                     0 \\
#                         CORDOBA &                              COLON &                          3153 &                     0 \\
#                         CORDOBA &                      MARCOS JUAREZ &                          2769 &                     2 \\
#                         CORDOBA &                              UNION &                          2464 &                     0 \\
#                         CORDOBA &                     TERCERO ARRIBA &                          2456 &                     0 \\
#                         CORDOBA &                        RIO SEGUNDO &                          2312 &                     0 \\
#                         CORDOBA &                        SANTA MARIA &                          1831 &                     2 \\
#                         CORDOBA &                      JUAREZ CELMAN &                          1765 &                     1 \\
#                         CORDOBA &                        RIO PRIMERO &                          1181 &                     3 \\
#                         CORDOBA &                       GENERAL ROCA &                          1067 &                     0 \\
#                         CORDOBA &                        CALAMUCHITA &                          1001 &                     1 \\
#                         CORDOBA &        PRESIDENTE ROQUE SAENZ PEÑA &                           929 &                     0 \\
#                         CORDOBA &                         SAN JAVIER &                           630 &                     1 \\
#                         CORDOBA &                       CRUZ DEL EJE &                           409 &                     1 \\
#                         CORDOBA &                        SAN ALBERTO &                           395 &                     0 \\
#                         CORDOBA &                            TOTORAL &                           382 &                     0 \\
#                         CORDOBA &                           ISCHILIN &                           254 &                     1 \\
#                         CORDOBA &                           RIO SECO &                           150 &                     2 \\
#                         CORDOBA &                            TULUMBA &                           127 &                     0 \\
#                         CORDOBA &                         SOBREMONTE &                            41 &                     0 \\
#                         CORDOBA &                              MINAS &                            22 &                     0 \\
#                         CORDOBA &                              POCHO &                            16 &                     0 \\
#                      CORRIENTES &                            CAPITAL &                          4359 &                     0 \\
#                      CORRIENTES &                               GOYA &                           842 &                     0 \\
#                      CORRIENTES &                         SANTO TOME &                           838 &                     0 \\
#                      CORRIENTES &                 PASO DE LOS LIBRES &                           606 &                     0 \\
#                      CORRIENTES &                      CURUZU CUATIA &                           578 &                     3 \\
#                      CORRIENTES &                           MERCEDES &                           531 &                     0 \\
#                      CORRIENTES &                      MONTE CASEROS &                           520 &                     0 \\
#                      CORRIENTES &                          ITUZAINGO &                           412 &                     0 \\
#                      CORRIENTES &                        BELLA VISTA &                           338 &                     3 \\
#                      CORRIENTES &                            ESQUINA &                           229 &                     0 \\
#                      CORRIENTES &                          SAN COSME &                           172 &                     0 \\
#                      CORRIENTES &                            LAVALLE &                           171 &                     0 \\
#                      CORRIENTES &                            SALADAS &                           159 &                     0 \\
#                      CORRIENTES &                          SAN ROQUE &                           145 &                     0 \\
#                      CORRIENTES &                         CONCEPCION &                           131 &                     0 \\
#                      CORRIENTES &                         SAN MARTIN &                           120 &                     2 \\
#                      CORRIENTES &                              SAUCE &                            99 &                     0 \\
#                      CORRIENTES &                        GENERAL PAZ &                            92 &                     0 \\
#                      CORRIENTES &                          EMPEDRADO &                            78 &                     0 \\
#                      CORRIENTES &                     GENERAL ALVEAR &                            66 &                     3 \\
#                      CORRIENTES &                SAN LUIS DEL PALMAR &                            66 &                     0 \\
#                      CORRIENTES &                              ITATI &                            51 &                     0 \\
#                      CORRIENTES &                         SAN MIGUEL &                            51 &                     0 \\
#                      CORRIENTES &                          MBURUCUYA &                            45 &                     0 \\
#                      CORRIENTES &                   BERON DE ASTRADA &                            19 &                     0 \\
#                      ENTRE RIOS &                             PARANA &                          6141 &                     1 \\
#                      ENTRE RIOS &                          CONCORDIA &                          2429 &                    18 \\
#                      ENTRE RIOS &                       GUALEGUAYCHU &                          2115 &                     0 \\
#                      ENTRE RIOS &                            URUGUAY &                          1618 &                    10 \\
#                      ENTRE RIOS &                         FEDERACION &                          1238 &                     4 \\
#                      ENTRE RIOS &                              COLON &                          1201 &                     1 \\
#                      ENTRE RIOS &                          GUALEGUAY &                           889 &                     2 \\
#                      ENTRE RIOS &                             LA PAZ &                           787 &                     3 \\
#                      ENTRE RIOS &                           DIAMANTE &                           773 &                     0 \\
#                      ENTRE RIOS &                          VILLAGUAY &                           704 &                     1 \\
#                      ENTRE RIOS &                           VICTORIA &                           625 &                     3 \\
#                      ENTRE RIOS &                             NOGOYA &                           574 &                     0 \\
#                      ENTRE RIOS &                       SAN SALVADOR &                           391 &                     3 \\
#                      ENTRE RIOS &                            FEDERAL &                           361 &                     1 \\
#                      ENTRE RIOS &                               TALA &                           360 &                     0 \\
#                      ENTRE RIOS &                          FELICIANO &                           148 &                     0 \\
#                      ENTRE RIOS &                   ISLAS DEL IBICUY &                           106 &                     0 \\
#                         FORMOSA &                            FORMOSA &                          2037 &                     0 \\
#                         FORMOSA &                          PILCOMAYO &                           457 &                     2 \\
#                         FORMOSA &                             PIRANE &                           324 &                     0 \\
#                         FORMOSA &                             PATIÑO &                           317 &                     0 \\
#                         FORMOSA &                             LAISHI &                            73 &                     0 \\
#                         FORMOSA &                            MATACOS &                            53 &                     0 \\
#                         FORMOSA &                            PILAGAS &                            42 &                     0 \\
#                         FORMOSA &                            BERMEJO &                            38 &                     0 \\
#                         FORMOSA &                        RAMON LISTA &                             1 &                     0 \\
#                           JUJUY &                DR. MANUEL BELGRANO &                          3007 &                     0 \\
#                           JUJUY &                          EL CARMEN &                          1262 &                     6 \\
#                           JUJUY &                            LEDESMA &                           494 &                     1 \\
#                           JUJUY &                          SAN PEDRO &                           446 &                     3 \\
#                           JUJUY &                            PALPALA &                           336 &                     0 \\
#                           JUJUY &                               YAVI &                           140 &                     0 \\
#                           JUJUY &                          COCHINOCA &                           123 &                     0 \\
#                           JUJUY &                            TILCARA &                            99 &                     0 \\
#                           JUJUY &                          HUMAHUACA &                            81 &                     0 \\
#                           JUJUY &                            TUMBAYA &                            64 &                     0 \\
#                           JUJUY &                      SANTA BARBARA &                            61 &                     2 \\
#                           JUJUY &                            SUSQUES &                            35 &                     0 \\
#                           JUJUY &                          RINCONADA &                            30 &                     0 \\
#                           JUJUY &                        SAN ANTONIO &                            29 &                     0 \\
#                           JUJUY &                     SANTA CATALINA &                             9 &                     0 \\
#                           JUJUY &                       VALLE GRANDE &                             8 &                     0 \\
#                        LA PAMPA &                            CAPITAL &                          2688 &                     0 \\
#                        LA PAMPA &                             MARACO &                          1557 &                     0 \\
#                        LA PAMPA &                            REALICO &                           446 &                     0 \\
#                        LA PAMPA &                            CONHELO &                           333 &                     0 \\
#                        LA PAMPA &                         CHAPALEUFU &                           316 &                     0 \\
#                        LA PAMPA &                            UTRACAN &                           300 &                     1 \\
#                        LA PAMPA &                            ATREUCO &                           296 &                     0 \\
#                        LA PAMPA &                        QUEMU QUEMU &                           253 &                     1 \\
#                        LA PAMPA &                             RANCUL &                           223 &                     0 \\
#                        LA PAMPA &                            CATRILO &                           215 &                     0 \\
#                        LA PAMPA &                               TOAY &                           201 &                     0 \\
#                        LA PAMPA &                          GUATRACHE &                           189 &                     0 \\
#                        LA PAMPA &                              HUCAL &                           167 &                     0 \\
#                        LA PAMPA &                             PUELEN &                           156 &                     0 \\
#                        LA PAMPA &                           LOVENTUE &                           150 &                     0 \\
#                        LA PAMPA &                             TRENEL &                           129 &                     0 \\
#                        LA PAMPA &                      LIMAY MAHUIDA &                            26 &                     0 \\
#                        LA PAMPA &                             CURACO &                            23 &                     0 \\
#                        LA PAMPA &                        CALEU CALEU &                            22 &                     1 \\
#                        LA PAMPA &                           CHALILEO &                            17 &                     0 \\
#                        LA PAMPA &                          CHICAL CO &                            11 &                     0 \\
#                        LA PAMPA &                       LIHUEL CALEL &                             8 &                     0 \\
#                        LA RIOJA &                            CAPITAL &                          2008 &                     4 \\
#                        LA RIOJA &                          CHILECITO &                           514 &                    31 \\
#                        LA RIOJA &                             ARAUCO &                           165 &                     9 \\
#                        LA RIOJA &                           CHAMICAL &                           107 &                     0 \\
#                        LA RIOJA &              ROSARIO VERA PEÑALOZA &                            79 &                     0 \\
#                        LA RIOJA &              CORONEL FELIPE VARELA &                            55 &                     2 \\
#                        LA RIOJA &                   GENERAL BELGRANO &                            36 &                     0 \\
#                        LA RIOJA &                      CASTRO BARROS &                            24 &                     0 \\
#                        LA RIOJA &                     GENERAL OCAMPO &                            22 &                     2 \\
#                        LA RIOJA &                           FAMATINA &                            21 &                     0 \\
#                        LA RIOJA &                           VINCHINA &                            14 &                     0 \\
#                        LA RIOJA &                 GENERAL SAN MARTIN &                            12 &                     0 \\
#                        LA RIOJA &             SAN BLAS DE LOS SAUCES &                             9 &                     0 \\
#                        LA RIOJA &                          SANAGASTA &                             7 &                     0 \\
#                        LA RIOJA &                      INDEPENDENCIA &                             5 &                     0 \\
#                        LA RIOJA &                   GENERAL LAMADRID &                             4 &                     0 \\
#                        LA RIOJA &          GENERAL ANGEL V. PEÑALOZA &                             2 &                     0 \\
#                        LA RIOJA &       GENERAL JUAN FACUNDO QUIROGA &                             1 &                     0 \\
#                         MENDOZA &                         GUAYMALLEN &                          7230 &                    12 \\
#                         MENDOZA &                            CAPITAL &                          3225 &                     2 \\
#                         MENDOZA &                         SAN RAFAEL &                          2931 &                    27 \\
#                         MENDOZA &                              MAIPU &                          2647 &                    27 \\
#                         MENDOZA &                      LUJAN DE CUYO &                          2244 &                    44 \\
#                         MENDOZA &                         GODOY CRUZ &                          2163 &                     3 \\
#                         MENDOZA &                         SAN MARTIN &                          1995 &                    13 \\
#                         MENDOZA &                          LAS HERAS &                          1269 &                     1 \\
#                         MENDOZA &                          RIVADAVIA &                          1016 &                     9 \\
#                         MENDOZA &                            TUNUYAN &                           730 &                    12 \\
#                         MENDOZA &                     GENERAL ALVEAR &                           653 &                     2 \\
#                         MENDOZA &                          TUPUNGATO &                           584 &                    13 \\
#                         MENDOZA &                         SAN CARLOS &                           523 &                    14 \\
#                         MENDOZA &                              JUNIN &                           502 &                    10 \\
#                         MENDOZA &                           MALARGÜE &                           385 &                     1 \\
#                         MENDOZA &                            LAVALLE &                           376 &                     3 \\
#                         MENDOZA &                         SANTA ROSA &                           286 &                     9 \\
#                         MENDOZA &                             LA PAZ &                            58 &                     5 \\
#                        MISIONES &                            CAPITAL &                          4250 &                     1 \\
#                        MISIONES &                              OBERA &                          1491 &                    10 \\
#                        MISIONES &                           CAINGUAS &                           892 &                     0 \\
#                        MISIONES &                             IGUAZU &                           876 &                     1 \\
#                        MISIONES &                           ELDORADO &                           787 &                     0 \\
#                        MISIONES &                    LEANDRO N. ALEM &                           575 &                     0 \\
#                        MISIONES &                          APOSTOLES &                           502 &                     1 \\
#                        MISIONES &                            GUARANI &                           483 &                     0 \\
#                        MISIONES &      LIBERTADOR GENERAL SAN MARTIN &                           482 &                    12 \\
#                        MISIONES &                        SAN IGNACIO &                           479 &                    10 \\
#                        MISIONES &                         MONTECARLO &                           405 &                     2 \\
#                        MISIONES &            GENERAL MANUEL BELGRANO &                           328 &                     1 \\
#                        MISIONES &                         25 DE MAYO &                           146 &                     0 \\
#                        MISIONES &                         CONCEPCION &                           136 &                     0 \\
#                        MISIONES &                         CANDELARIA &                           122 &                     0 \\
#                        MISIONES &                         SAN JAVIER &                           120 &                   181 \\
#                        MISIONES &                          SAN PEDRO &                            18 &                     0 \\
#                         NEUQUEN &                        CONFLUENCIA &                          8312 &                    47 \\
#                         NEUQUEN &                              LACAR &                           988 &                     0 \\
#                         NEUQUEN &                          LOS LAGOS &                           493 &                     0 \\
#                         NEUQUEN &                             ZAPALA &                           425 &                     0 \\
#                         NEUQUEN &                         PEHUENCHES &                           412 &                     0 \\
#                         NEUQUEN &                              AÑELO &                           258 &                    20 \\
#                         NEUQUEN &                          HUILICHES &                           214 &                     0 \\
#                         NEUQUEN &                         CHOS MALAL &                           210 &                     0 \\
#                         NEUQUEN &                            ALUMINE &                           108 &                     0 \\
# ...
#                           SALTA &             ROSARIO DE LA FRONTERA &                           290 &                     3 \\
#                           SALTA &                           CAFAYATE &                           226 &                     5 \\
#                           SALTA &                          LOS ANDES &                            87 &                     0 \\
#                           SALTA &                      LA CANDELARIA &                            74 &                     0 \\
#                           SALTA &                          RIVADAVIA &                            64 &                     0 \\
#                           SALTA &                            LA VIÑA &                            49 &                     0 \\
#                           SALTA &                          GUACHIPAS &                            43 &                     1 \\
#                           SALTA &                              CACHI &                            41 &                     1 \\
#                           SALTA &                         LA CALDERA &                            28 &                     0 \\
#                           SALTA &                            MOLINOS &                            28 &                     0 \\
#                           SALTA &                            LA POMA &                             8 &                     0 \\
#                           SALTA &                         SAN CARLOS &                             8 &                     1 \\
#                           SALTA &                     SANTA VICTORIA &                             3 &                     0 \\
#                           SALTA &                              IRUYA &                             2 &                     0 \\
#                        SAN JUAN &                            CAPITAL &                          4443 &                     0 \\
#                        SAN JUAN &                             RAWSON &                           759 &                    10 \\
#                        SAN JUAN &                        SANTA LUCIA &                           539 &                     3 \\
#                        SAN JUAN &                             POCITO &                           484 &                     2 \\
#                        SAN JUAN &                          RIVADAVIA &                           464 &                     0 \\
#                        SAN JUAN &                            CHIMBAS &                           448 &                     1 \\
#                        SAN JUAN &                            CAUCETE &                           387 &                     9 \\
#                        SAN JUAN &                          SARMIENTO &                           265 &                     2 \\
#                        SAN JUAN &                           ALBARDON &                           199 &                     2 \\
#                        SAN JUAN &                             JACHAL &                           188 &                     0 \\
#                        SAN JUAN &                         25 DE MAYO &                           158 &                     5 \\
#                        SAN JUAN &                            IGLESIA &                           136 &                     0 \\
#                        SAN JUAN &                         CALINGASTA &                           133 &                     1 \\
#                        SAN JUAN &                         9 DE JULIO &                            78 &                     4 \\
#                        SAN JUAN &                         SAN MARTIN &                            73 &                     4 \\
#                        SAN JUAN &                             ANGACO &                            50 &                     1 \\
#                        SAN JUAN &                       VALLE FERTIL &                            43 &                     0 \\
#                        SAN JUAN &                              ZONDA &                            11 &                     0 \\
#                        SAN JUAN &                              ULLUM &                             5 &                     0 \\
#                        SAN LUIS &             JUAN MARTIN PUEYRREDON &                          3091 &                     0 \\
#                        SAN LUIS &             JUAN MARTIN PUEYRREDON &                          3091 &                     0 \\
#                        SAN LUIS &                         LA CAPITAL &                          3091 &                     0 \\
#                        SAN LUIS &                         LA CAPITAL &                          3091 &                     0 \\
#                        SAN LUIS &                  GENERAL PEDERNERA &                          1797 &                     0 \\
#                        SAN LUIS &                              JUNIN &                           477 &                     1 \\
#                        SAN LUIS &                          CHACABUCO &                           272 &                     0 \\
#                        SAN LUIS &                   GOBERNADOR DUPUY &                           221 &                     0 \\
#                        SAN LUIS &                   CORONEL PRINGLES &                           219 &                     1 \\
#                        SAN LUIS &                           AYACUCHO &                           130 &                     3 \\
#                        SAN LUIS &      LIBERTADOR GENERAL SAN MARTIN &                            27 &                     0 \\
#                        SAN LUIS &                           BELGRANO &                            21 &                     0 \\
#                      SANTA CRUZ &                          GÜER AIKE &                          1883 &                     4 \\
#                      SANTA CRUZ &                            DESEADO &                          1679 &                     6 \\
#                      SANTA CRUZ &                     LAGO ARGENTINO &                           612 &                     0 \\
#                      SANTA CRUZ &                  LAGO BUENOS AIRES &                           238 &                     0 \\
#                      SANTA CRUZ &                         MAGALLANES &                           202 &                     1 \\
#                      SANTA CRUZ &                        CORPEN AIKE &                           165 &                     0 \\
#                      SANTA CRUZ &                          RIO CHICO &                            88 &                     0 \\
#                        SANTA FE &                            ROSARIO &                         25338 &                     6 \\
#                        SANTA FE &                         LA CAPITAL &                          7665 &                     3 \\
#                        SANTA FE &                      GENERAL LOPEZ &                          5159 &                     0 \\
#                        SANTA FE &                        CASTELLANOS &                          3982 &                     0 \\
#                        SANTA FE &                        SAN LORENZO &                          3219 &                     2 \\
#                        SANTA FE &                       LAS COLONIAS &                          2640 &                     0 \\
#                        SANTA FE &                   GENERAL OBLIGADO &                          2605 &                     2 \\
#                        SANTA FE &                            CASEROS &                          2079 &                     1 \\
#                        SANTA FE &                            IRIONDO &                          1617 &                     0 \\
#                        SANTA FE &                       CONSTITUCION &                          1570 &                     0 \\
#                        SANTA FE &                       SAN JERONIMO &                          1549 &                     1 \\
#                        SANTA FE &                         SAN MARTIN &                          1529 &                     0 \\
#                        SANTA FE &                      SAN CRISTOBAL &                          1437 &                     0 \\
#                        SANTA FE &                           BELGRANO &                          1258 &                     2 \\
#                        SANTA FE &                          SAN JUSTO &                           793 &                     0 \\
#                        SANTA FE &                               VERA &                           629 &                     0 \\
#                        SANTA FE &                         9 DE JULIO &                           492 &                     1 \\
#                        SANTA FE &                         SAN JAVIER &                           373 &                     6 \\
#                        SANTA FE &                              GARAY &                           271 &                     0 \\
#             SANTIAGO DEL ESTERO &                            CAPITAL &                          3335 &                     8 \\
#             SANTIAGO DEL ESTERO &                              BANDA &                           931 &                     0 \\
#             SANTIAGO DEL ESTERO &                          RIO HONDO &                           320 &                     1 \\
#             SANTIAGO DEL ESTERO &                             MORENO &                           305 &                     0 \\
#             SANTIAGO DEL ESTERO &                              CHOYA &                           282 &                     0 \\
#             SANTIAGO DEL ESTERO &                           BELGRANO &                           256 &                     0 \\
#             SANTIAGO DEL ESTERO &                    GENERAL TABOADA &                           202 &                     0 \\
#             SANTIAGO DEL ESTERO &                             ROBLES &                           196 &                     0 \\
#             SANTIAGO DEL ESTERO &                               COPO &                           142 &                     0 \\
#             SANTIAGO DEL ESTERO &                             LA PAZ &                           107 &                     0 \\
#             SANTIAGO DEL ESTERO &                             LA PAZ &                           107 &                     0 \\
#             SANTIAGO DEL ESTERO &                          RIVADAVIA &                           100 &                     0 \\
#             SANTIAGO DEL ESTERO &                         PELLEGRINI &                            86 &                     0 \\
#             SANTIAGO DEL ESTERO &                             LORETO &                            82 &                     0 \\
#             SANTIAGO DEL ESTERO &                            ALBERDI &                            77 &                     0 \\
#             SANTIAGO DEL ESTERO &                        OJO DE AGUA &                            65 &                     0 \\
#             SANTIAGO DEL ESTERO &                            AGUIRRE &                            51 &                     0 \\
#             SANTIAGO DEL ESTERO &                         QUEBRACHOS &                            51 &                     1 \\
#             SANTIAGO DEL ESTERO &                            JIMENEZ &                            49 &                     0 \\
#             SANTIAGO DEL ESTERO &                         AVELLANEDA &                            48 &                     0 \\
#             SANTIAGO DEL ESTERO &                 JUAN FELIPE IBARRA &                            37 &                     0 \\
#             SANTIAGO DEL ESTERO &                           FIGUEROA &                            25 &                     0 \\
#             SANTIAGO DEL ESTERO &                           GUASAYAN &                            23 &                     0 \\
#             SANTIAGO DEL ESTERO &                           GUASAYAN &                            23 &                     0 \\
#             SANTIAGO DEL ESTERO &                           SALAVINA &                            21 &                     0 \\
#             SANTIAGO DEL ESTERO &                          SARMIENTO &                            20 &                     0 \\
#             SANTIAGO DEL ESTERO &                         SAN MARTIN &                            16 &                     0 \\
#             SANTIAGO DEL ESTERO &                           SILIPICA &                            16 &                     0 \\
#             SANTIAGO DEL ESTERO &                          ATAMISQUI &                             8 &                     0 \\
#             SANTIAGO DEL ESTERO &                              MITRE &                             4 &                     0 \\
#                TIERRA DEL FUEGO &                            USHUAIA &                          1652 &                     0 \\
#                TIERRA DEL FUEGO &                         RIO GRANDE &                          1563 &                     3 \\
#                TIERRA DEL FUEGO &            ISLAS DEL ATLANTICO SUR &                             0 &                     0 \\
#                         TUCUMAN &                            CAPITAL &                          8679 &                     6 \\
#                         TUCUMAN &                        YERBA BUENA &                          1358 &                     2 \\
#                         TUCUMAN &                          CRUZ ALTA &                          1019 &                     0 \\
#                         TUCUMAN &                        CHICLIGASTA &                           711 &                     2 \\
#                         TUCUMAN &                         TAFI VIEJO &                           704 &                     0 \\
#                         TUCUMAN &                           MONTEROS &                           440 &                    15 \\
#                         TUCUMAN &                              LULES &                           325 &                     2 \\
#                         TUCUMAN &                          RIO CHICO &                           271 &                     2 \\
#                         TUCUMAN &                           FAMAILLA &                           269 &                     4 \\
#                         TUCUMAN &              JUAN BAUTISTA ALBERDI &                           264 &                     3 \\
#                         TUCUMAN &                             LEALES &                           194 &                     0 \\
#                         TUCUMAN &                          BURRUYACU &                           173 &                     0 \\
#                         TUCUMAN &                     TAFI DEL VALLE &                           129 &                     0 \\
#                         TUCUMAN &                             SIMOCA &                           124 &                     0 \\
#                         TUCUMAN &                            TRANCAS &                           122 &                     0 \\
#                         TUCUMAN &                           LA COCHA &                            98 &                     2 \\
#                         TUCUMAN &                           GRANEROS &                            42 &                     1 \\
# \bottomrule
# \end{tabular}
# C:\Users\luisr\AppData\Local\Temp\ipykernel_16792\4273561937.py:4: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   tabla_latex = tabla.to_latex(index=False)

# %% [markdown]
# **RECU)** Listar la totalidad de las Provincias y sus Departamentos respetando el
# siguiente orden:
# 1. Las provincias con más departamentos al principio
# 2. En caso de empate, por orden alfabético de Nombre de Provincia
# 3. y dentro de provincia, por orden alfabético de nombre de
# Departamento

# %%
#obtenemos la cantidad de departamentos por provincia

query_aux = """
             SELECT p.id_provincia, COUNT(d.id_departamento) AS cantidad_departamentos
             FROM departamento AS d
             INNER JOIN provincia AS p
             ON d.id_provincia = p.id_provincia
             GROUP BY p.id_provincia
             ORDER BY cantidad_departamentos DESC
            """

cantidad_deptos = sql^ query_aux

#relacionamos a cada provincia con su cantidad de deptos

query_aux_2 = """
               SELECT p.id_provincia, p.Nombre AS Provincia, c.cantidad_departamentos
               FROM provincia AS p
               INNER JOIN cantidad_deptos AS c
               ON c.id_provincia = p.id_provincia
              """

provincias_con_cant_deptos = sql^ query_aux_2

#relacionamos a este nuevo dataframe con los deptos y vemos los resultados

query = """
          SELECT p.Provincia, d.Nombre AS Departamento
          FROM departamento AS d
          INNER JOIN provincias_con_cant_deptos AS p
          ON d.id_provincia = p.id_provincia
          ORDER BY p.cantidad_departamentos DESC, p.Provincia ASC, d.Nombre ASC
        """

provincias_con_mas_deptos = sql^ query

# %%
provincias_con_mas_deptos
# Out:
#                            Provincia                     Departamento
# 0                       BUENOS AIRES                       25 DE MAYO
# 1                       BUENOS AIRES                       9 DE JULIO
# 2                       BUENOS AIRES                    ADOLFO ALSINA
# 3                       BUENOS AIRES           ADOLFO GONZALES CHAVES
# 4                       BUENOS AIRES                          ALBERTI
# ..                               ...                              ...
# 512                       SANTA CRUZ                        RIO CHICO
# 513                 TIERRA DEL FUEGO          ISLAS DEL ATLANTICO SUR
# 514                 TIERRA DEL FUEGO                       RIO GRANDE
# 515                 TIERRA DEL FUEGO                          USHUAIA
# 516  CIUDAD AUTONOMA DE BUENOS AIRES  CIUDAD AUTONOMA DE BUENOS AIRES
#
# [517 rows x 2 columns]

# %%
pasar_latex(provincias_con_mas_deptos.head(6))
# Out:
# \begin{tabular}{ll}
# \toprule
#    Provincia &           Departamento \\
# \midrule
# BUENOS AIRES &             25 DE MAYO \\
# BUENOS AIRES &             9 DE JULIO \\
# BUENOS AIRES &          ADOLFO ALSINA \\
# BUENOS AIRES & ADOLFO GONZALES CHAVES \\
# BUENOS AIRES &                ALBERTI \\
# BUENOS AIRES &        ALMIRANTE BROWN \\
# \bottomrule
# \end{tabular}
# C:\Users\luisr\AppData\Local\Temp\ipykernel_16792\4273561937.py:4: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   tabla_latex = tabla.to_latex(index=False)

# %%
pasar_latex(provincias_con_mas_deptos)
# Out:
# \begin{tabular}{ll}
# \toprule
#                       Provincia &                       Departamento \\
# \midrule
#                    BUENOS AIRES &                         25 DE MAYO \\
#                    BUENOS AIRES &                         9 DE JULIO \\
#                    BUENOS AIRES &                      ADOLFO ALSINA \\
#                    BUENOS AIRES &             ADOLFO GONZALES CHAVES \\
#                    BUENOS AIRES &                            ALBERTI \\
#                    BUENOS AIRES &                    ALMIRANTE BROWN \\
#                    BUENOS AIRES &                          ARRECIFES \\
#                    BUENOS AIRES &                         AVELLANEDA \\
#                    BUENOS AIRES &                           AYACUCHO \\
#                    BUENOS AIRES &                               AZUL \\
#                    BUENOS AIRES &                       BAHIA BLANCA \\
#                    BUENOS AIRES &                           BALCARCE \\
#                    BUENOS AIRES &                           BARADERO \\
#                    BUENOS AIRES &                      BENITO JUAREZ \\
#                    BUENOS AIRES &                        BERAZATEGUI \\
#                    BUENOS AIRES &                            BERISSO \\
#                    BUENOS AIRES &                            BOLIVAR \\
#                    BUENOS AIRES &                            BRAGADO \\
#                    BUENOS AIRES &                           BRANDSEN \\
#                    BUENOS AIRES &                            CAMPANA \\
#                    BUENOS AIRES &                  CAPITAN SARMIENTO \\
#                    BUENOS AIRES &                     CARLOS CASARES \\
#                    BUENOS AIRES &                     CARLOS TEJEDOR \\
#                    BUENOS AIRES &                    CARMEN DE ARECO \\
#                    BUENOS AIRES &                           CASTELLI \\
#                    BUENOS AIRES &                           CAÑUELAS \\
#                    BUENOS AIRES &                          CHACABUCO \\
#                    BUENOS AIRES &                          CHASCOMUS \\
#                    BUENOS AIRES &                          CHIVILCOY \\
#                    BUENOS AIRES &                              COLON \\
#                    BUENOS AIRES & CORONEL DE MARINA LEONARDO ROSALES \\
#                    BUENOS AIRES &                    CORONEL DORREGO \\
#                    BUENOS AIRES &                   CORONEL PRINGLES \\
#                    BUENOS AIRES &                     CORONEL SUAREZ \\
#                    BUENOS AIRES &                           DAIREAUX \\
#                    BUENOS AIRES &                            DOLORES \\
#                    BUENOS AIRES &                           ENSENADA \\
#                    BUENOS AIRES &                            ESCOBAR \\
#                    BUENOS AIRES &                 ESTEBAN ECHEVERRIA \\
#                    BUENOS AIRES &              EXALTACION DE LA CRUZ \\
#                    BUENOS AIRES &                             EZEIZA \\
#                    BUENOS AIRES &                   FLORENCIO VARELA \\
#                    BUENOS AIRES &                FLORENTINO AMEGHINO \\
#                    BUENOS AIRES &                   GENERAL ALVARADO \\
#                    BUENOS AIRES &                     GENERAL ALVEAR \\
#                    BUENOS AIRES &                   GENERAL ARENALES \\
#                    BUENOS AIRES &                   GENERAL BELGRANO \\
#                    BUENOS AIRES &                      GENERAL GUIDO \\
#                    BUENOS AIRES &             GENERAL JUAN MADARIAGA \\
#                    BUENOS AIRES &                  GENERAL LA MADRID \\
#                    BUENOS AIRES &                  GENERAL LAS HERAS \\
#                    BUENOS AIRES &                    GENERAL LAVALLE \\
#                    BUENOS AIRES &                        GENERAL PAZ \\
#                    BUENOS AIRES &                      GENERAL PINTO \\
#                    BUENOS AIRES &                 GENERAL PUEYRREDON \\
#                    BUENOS AIRES &                  GENERAL RODRIGUEZ \\
#                    BUENOS AIRES &                 GENERAL SAN MARTIN \\
#                    BUENOS AIRES &                   GENERAL VIAMONTE \\
#                    BUENOS AIRES &                   GENERAL VILLEGAS \\
#                    BUENOS AIRES &                            GUAMINI \\
#                    BUENOS AIRES &                  HIPOLITO YRIGOYEN \\
#                    BUENOS AIRES &                         HURLINGHAM \\
#                    BUENOS AIRES &                          ITUZAINGO \\
#                    BUENOS AIRES &                        JOSE C. PAZ \\
#                    BUENOS AIRES &                              JUNIN \\
#                    BUENOS AIRES &                           LA COSTA \\
#                    BUENOS AIRES &                         LA MATANZA \\
#                    BUENOS AIRES &                           LA PLATA \\
#                    BUENOS AIRES &                              LANUS \\
#                    BUENOS AIRES &                            LAPRIDA \\
#                    BUENOS AIRES &                         LAS FLORES \\
#                    BUENOS AIRES &                    LEANDRO N. ALEM \\
#                    BUENOS AIRES &                             LEZAMA \\
#                    BUENOS AIRES &                            LINCOLN \\
#                    BUENOS AIRES &                            LOBERIA \\
#                    BUENOS AIRES &                              LOBOS \\
#                    BUENOS AIRES &                    LOMAS DE ZAMORA \\
#                    BUENOS AIRES &                              LUJAN \\
#                    BUENOS AIRES &                          MAGDALENA \\
#                    BUENOS AIRES &                              MAIPU \\
#                    BUENOS AIRES &                MALVINAS ARGENTINAS \\
#                    BUENOS AIRES &                       MAR CHIQUITA \\
#                    BUENOS AIRES &                         MARCOS PAZ \\
#                    BUENOS AIRES &                           MERCEDES \\
#                    BUENOS AIRES &                              MERLO \\
#                    BUENOS AIRES &                              MONTE \\
#                    BUENOS AIRES &                      MONTE HERMOSO \\
#                    BUENOS AIRES &                             MORENO \\
#                    BUENOS AIRES &                              MORON \\
#                    BUENOS AIRES &                            NAVARRO \\
#                    BUENOS AIRES &                           NECOCHEA \\
#                    BUENOS AIRES &                          OLAVARRIA \\
#                    BUENOS AIRES &                          PATAGONES \\
#                    BUENOS AIRES &                            PEHUAJO \\
#                    BUENOS AIRES &                         PELLEGRINI \\
#                    BUENOS AIRES &                          PERGAMINO \\
#                    BUENOS AIRES &                               PILA \\
#                    BUENOS AIRES &                              PILAR \\
#                    BUENOS AIRES &                            PINAMAR \\
#                    BUENOS AIRES &                   PRESIDENTE PERON \\
#                    BUENOS AIRES &                               PUAN \\
#                    BUENOS AIRES &                        PUNTA INDIO \\
#                    BUENOS AIRES &                            QUILMES \\
#                    BUENOS AIRES &                            RAMALLO \\
#                    BUENOS AIRES &                              RAUCH \\
#                    BUENOS AIRES &                          RIVADAVIA \\
#                    BUENOS AIRES &                              ROJAS \\
#                    BUENOS AIRES &                        ROQUE PEREZ \\
#                    BUENOS AIRES &                           SAAVEDRA \\
#                    BUENOS AIRES &                          SALADILLO \\
#                    BUENOS AIRES &                         SALLIQUELO \\
#                    BUENOS AIRES &                              SALTO \\
#                    BUENOS AIRES &                SAN ANDRES DE GILES \\
#                    BUENOS AIRES &               SAN ANTONIO DE ARECO \\
#                    BUENOS AIRES &                       SAN CAYETANO \\
#                    BUENOS AIRES &                       SAN FERNANDO \\
#                    BUENOS AIRES &                         SAN ISIDRO \\
#                    BUENOS AIRES &                         SAN MIGUEL \\
#                    BUENOS AIRES &                        SAN NICOLAS \\
#                    BUENOS AIRES &                          SAN PEDRO \\
#                    BUENOS AIRES &                        SAN VICENTE \\
#                    BUENOS AIRES &                           SUIPACHA \\
#                    BUENOS AIRES &                             TANDIL \\
#                    BUENOS AIRES &                           TAPALQUE \\
#                    BUENOS AIRES &                              TIGRE \\
#                    BUENOS AIRES &                           TORDILLO \\
#                    BUENOS AIRES &                          TORNQUIST \\
#                    BUENOS AIRES &                    TRENQUE LAUQUEN \\
#                    BUENOS AIRES &                       TRES ARROYOS \\
#                    BUENOS AIRES &                    TRES DE FEBRERO \\
#                    BUENOS AIRES &                         TRES LOMAS \\
#                    BUENOS AIRES &                      VICENTE LOPEZ \\
#                    BUENOS AIRES &                       VILLA GESELL \\
#                    BUENOS AIRES &                          VILLARINO \\
#                    BUENOS AIRES &                             ZARATE \\
#             SANTIAGO DEL ESTERO &                            AGUIRRE \\
#             SANTIAGO DEL ESTERO &                            ALBERDI \\
#             SANTIAGO DEL ESTERO &                          ATAMISQUI \\
#             SANTIAGO DEL ESTERO &                         AVELLANEDA \\
#             SANTIAGO DEL ESTERO &                              BANDA \\
#             SANTIAGO DEL ESTERO &                           BELGRANO \\
#             SANTIAGO DEL ESTERO &                            CAPITAL \\
#             SANTIAGO DEL ESTERO &                              CHOYA \\
#             SANTIAGO DEL ESTERO &                               COPO \\
#             SANTIAGO DEL ESTERO &                           FIGUEROA \\
#             SANTIAGO DEL ESTERO &                    GENERAL TABOADA \\
#             SANTIAGO DEL ESTERO &                           GUASAYAN \\
#             SANTIAGO DEL ESTERO &                            JIMENEZ \\
#             SANTIAGO DEL ESTERO &                 JUAN FELIPE IBARRA \\
#             SANTIAGO DEL ESTERO &                             LA PAZ \\
#             SANTIAGO DEL ESTERO &                             LORETO \\
#             SANTIAGO DEL ESTERO &                              MITRE \\
#             SANTIAGO DEL ESTERO &                             MORENO \\
#             SANTIAGO DEL ESTERO &                        OJO DE AGUA \\
#             SANTIAGO DEL ESTERO &                         PELLEGRINI \\
#             SANTIAGO DEL ESTERO &                         QUEBRACHOS \\
#             SANTIAGO DEL ESTERO &                          RIO HONDO \\
#             SANTIAGO DEL ESTERO &                          RIVADAVIA \\
#             SANTIAGO DEL ESTERO &                             ROBLES \\
#             SANTIAGO DEL ESTERO &                           SALAVINA \\
#             SANTIAGO DEL ESTERO &                         SAN MARTIN \\
#             SANTIAGO DEL ESTERO &                          SARMIENTO \\
#             SANTIAGO DEL ESTERO &                           SILIPICA \\
#                         CORDOBA &                        CALAMUCHITA \\
#                         CORDOBA &                            CAPITAL \\
#                         CORDOBA &                              COLON \\
#                         CORDOBA &                       CRUZ DEL EJE \\
#                         CORDOBA &                       GENERAL ROCA \\
#                         CORDOBA &                 GENERAL SAN MARTIN \\
#                         CORDOBA &                           ISCHILIN \\
#                         CORDOBA &                      JUAREZ CELMAN \\
#                         CORDOBA &                      MARCOS JUAREZ \\
#                         CORDOBA &                              MINAS \\
#                         CORDOBA &                              POCHO \\
#                         CORDOBA &        PRESIDENTE ROQUE SAENZ PEÑA \\
#                         CORDOBA &                            PUNILLA \\
#                         CORDOBA &                         RIO CUARTO \\
#                         CORDOBA &                        RIO PRIMERO \\
#                         CORDOBA &                           RIO SECO \\
#                         CORDOBA &                        RIO SEGUNDO \\
#                         CORDOBA &                        SAN ALBERTO \\
#                         CORDOBA &                         SAN JAVIER \\
#                         CORDOBA &                          SAN JUSTO \\
#                         CORDOBA &                        SANTA MARIA \\
#                         CORDOBA &                         SOBREMONTE \\
#                         CORDOBA &                     TERCERO ARRIBA \\
#                         CORDOBA &                            TOTORAL \\
#                         CORDOBA &                            TULUMBA \\
#                         CORDOBA &                              UNION \\
#                           CHACO &                      12 DE OCTUBRE \\
#                           CHACO &                         1º DE MAYO \\
#                           CHACO &                         2 DE ABRIL \\
#                           CHACO &                         25 DE MAYO \\
#                           CHACO &                         9 DE JULIO \\
#                           CHACO &                    ALMIRANTE BROWN \\
#                           CHACO &                            BERMEJO \\
#                           CHACO &                          CHACABUCO \\
#                           CHACO &               COMANDANTE FERNANDEZ \\
#                           CHACO &      FRAY JUSTO SANTA MARIA DE ORO \\
#                           CHACO &                   GENERAL BELGRANO \\
#                           CHACO &                    GENERAL DONOVAN \\
#                           CHACO &                     GENERAL GÜEMES \\
#                           CHACO &                      INDEPENDENCIA \\
#                           CHACO &                           LIBERTAD \\
#                           CHACO &      LIBERTADOR GENERAL SAN MARTIN \\
#                           CHACO &                              MAIPU \\
#                           CHACO &              MAYOR LUIS J. FONTANA \\
#                           CHACO &                          O'HIGGINS \\
#                           CHACO &            PRESIDENCIA DE LA PLAZA \\
#                           CHACO &                          QUITILIPI \\
#                           CHACO &                       SAN FERNANDO \\
#                           CHACO &                        SAN LORENZO \\
#                           CHACO &                    SARGENTO CABRAL \\
#                           CHACO &                           TAPENAGA \\
#                      CORRIENTES &                        BELLA VISTA \\
#                      CORRIENTES &                   BERON DE ASTRADA \\
#                      CORRIENTES &                            CAPITAL \\
#                      CORRIENTES &                         CONCEPCION \\
#                      CORRIENTES &                      CURUZU CUATIA \\
#                      CORRIENTES &                          EMPEDRADO \\
#                      CORRIENTES &                            ESQUINA \\
#                      CORRIENTES &                     GENERAL ALVEAR \\
#                      CORRIENTES &                        GENERAL PAZ \\
#                      CORRIENTES &                               GOYA \\
#                      CORRIENTES &                              ITATI \\
#                      CORRIENTES &                          ITUZAINGO \\
#                      CORRIENTES &                            LAVALLE \\
#                      CORRIENTES &                          MBURUCUYA \\
#                      CORRIENTES &                           MERCEDES \\
#                      CORRIENTES &                      MONTE CASEROS \\
#                      CORRIENTES &                 PASO DE LOS LIBRES \\
#                      CORRIENTES &                            SALADAS \\
#                      CORRIENTES &                          SAN COSME \\
#                      CORRIENTES &                SAN LUIS DEL PALMAR \\
#                      CORRIENTES &                         SAN MARTIN \\
#                      CORRIENTES &                         SAN MIGUEL \\
#                      CORRIENTES &                          SAN ROQUE \\
#                      CORRIENTES &                         SANTO TOME \\
#                      CORRIENTES &                              SAUCE \\
#                           SALTA &                               ANTA \\
#                           SALTA &                              CACHI \\
#                           SALTA &                           CAFAYATE \\
#                           SALTA &                            CAPITAL \\
#                           SALTA &                          CERRILLOS \\
#                           SALTA &                           CHICOANA \\
#                           SALTA &                     GENERAL GÜEMES \\
#                           SALTA &         GENERAL JOSE DE SAN MARTIN \\
#                           SALTA &                          GUACHIPAS \\
#                           SALTA &                              IRUYA \\
#                           SALTA &                         LA CALDERA \\
#                           SALTA &                      LA CANDELARIA \\
#                           SALTA &                            LA POMA \\
#                           SALTA &                            LA VIÑA \\
#                           SALTA &                          LOS ANDES \\
#                           SALTA &                              METAN \\
#                           SALTA &                            MOLINOS \\
#                           SALTA &                               ORAN \\
#                           SALTA &                          RIVADAVIA \\
#                           SALTA &             ROSARIO DE LA FRONTERA \\
#                           SALTA &                   ROSARIO DE LERMA \\
#                           SALTA &                         SAN CARLOS \\
#                           SALTA &                     SANTA VICTORIA \\
#                        LA PAMPA &                            ATREUCO \\
#                        LA PAMPA &                        CALEU CALEU \\
#                        LA PAMPA &                            CAPITAL \\
#                        LA PAMPA &                            CATRILO \\
#                        LA PAMPA &                           CHALILEO \\
#                        LA PAMPA &                         CHAPALEUFU \\
#                        LA PAMPA &                          CHICAL CO \\
#                        LA PAMPA &                            CONHELO \\
#                        LA PAMPA &                             CURACO \\
#                        LA PAMPA &                          GUATRACHE \\
#                        LA PAMPA &                              HUCAL \\
#                        LA PAMPA &                       LIHUEL CALEL \\
#                        LA PAMPA &                      LIMAY MAHUIDA \\
#                        LA PAMPA &                           LOVENTUE \\
#                        LA PAMPA &                             MARACO \\
#                        LA PAMPA &                             PUELEN \\
#                        LA PAMPA &                        QUEMU QUEMU \\
#                        LA PAMPA &                             RANCUL \\
#                        LA PAMPA &                            REALICO \\
#                        LA PAMPA &                               TOAY \\
#                        LA PAMPA &                             TRENEL \\
#                        LA PAMPA &                            UTRACAN \\
#                        SAN JUAN &                         25 DE MAYO \\
#                        SAN JUAN &                         9 DE JULIO \\
#                        SAN JUAN &                           ALBARDON \\
#                        SAN JUAN &                             ANGACO \\
#                        SAN JUAN &                         CALINGASTA \\
#                        SAN JUAN &                            CAPITAL \\
#                        SAN JUAN &                            CAUCETE \\
#                        SAN JUAN &                            CHIMBAS \\
#                        SAN JUAN &                            IGLESIA \\
#                        SAN JUAN &                             JACHAL \\
#                        SAN JUAN &                             POCITO \\
#                        SAN JUAN &                             RAWSON \\
#                        SAN JUAN &                          RIVADAVIA \\
#                        SAN JUAN &                         SAN MARTIN \\
#                        SAN JUAN &                        SANTA LUCIA \\
#                        SAN JUAN &                          SARMIENTO \\
#                        SAN JUAN &                              ULLUM \\
#                        SAN JUAN &                       VALLE FERTIL \\
#                        SAN JUAN &                              ZONDA \\
#                        SANTA FE &                         9 DE JULIO \\
#                        SANTA FE &                           BELGRANO \\
#                        SANTA FE &                            CASEROS \\
#                        SANTA FE &                        CASTELLANOS \\
#                        SANTA FE &                       CONSTITUCION \\
#                        SANTA FE &                              GARAY \\
#                        SANTA FE &                      GENERAL LOPEZ \\
#                        SANTA FE &                   GENERAL OBLIGADO \\
#                        SANTA FE &                            IRIONDO \\
#                        SANTA FE &                         LA CAPITAL \\
#                        SANTA FE &                       LAS COLONIAS \\
#                        SANTA FE &                            ROSARIO \\
#                        SANTA FE &                      SAN CRISTOBAL \\
#                        SANTA FE &                         SAN JAVIER \\
#                        SANTA FE &                       SAN JERONIMO \\
#                        SANTA FE &                          SAN JUSTO \\
#                        SANTA FE &                        SAN LORENZO \\
#                        SANTA FE &                         SAN MARTIN \\
#                        SANTA FE &                               VERA \\
#                        LA RIOJA &                             ARAUCO \\
#                        LA RIOJA &                            CAPITAL \\
#                        LA RIOJA &                      CASTRO BARROS \\
#                        LA RIOJA &                           CHAMICAL \\
#                        LA RIOJA &                          CHILECITO \\
#                        LA RIOJA &              CORONEL FELIPE VARELA \\
#                        LA RIOJA &                           FAMATINA \\
#                        LA RIOJA &          GENERAL ANGEL V. PEÑALOZA \\
#                        LA RIOJA &                   GENERAL BELGRANO \\
#                        LA RIOJA &       GENERAL JUAN FACUNDO QUIROGA \\
#                        LA RIOJA &                   GENERAL LAMADRID \\
#                        LA RIOJA &                     GENERAL OCAMPO \\
#                        LA RIOJA &                 GENERAL SAN MARTIN \\
#                        LA RIOJA &                      INDEPENDENCIA \\
#                        LA RIOJA &              ROSARIO VERA PEÑALOZA \\
#                        LA RIOJA &             SAN BLAS DE LOS SAUCES \\
#                        LA RIOJA &                          SANAGASTA \\
#                        LA RIOJA &                           VINCHINA \\
#                         MENDOZA &                            CAPITAL \\
#                         MENDOZA &                     GENERAL ALVEAR \\
#                         MENDOZA &                         GODOY CRUZ \\
#                         MENDOZA &                         GUAYMALLEN \\
#                         MENDOZA &                              JUNIN \\
#                         MENDOZA &                             LA PAZ \\
#                         MENDOZA &                          LAS HERAS \\
#                         MENDOZA &                            LAVALLE \\
#                         MENDOZA &                      LUJAN DE CUYO \\
#                         MENDOZA &                              MAIPU \\
#                         MENDOZA &                           MALARGÜE \\
#                         MENDOZA &                          RIVADAVIA \\
#                         MENDOZA &                         SAN CARLOS \\
#                         MENDOZA &                         SAN MARTIN \\
#                         MENDOZA &                         SAN RAFAEL \\
#                         MENDOZA &                         SANTA ROSA \\
#                         MENDOZA &                            TUNUYAN \\
#                         MENDOZA &                          TUPUNGATO \\
#                       CATAMARCA &                             AMBATO \\
#                       CATAMARCA &                            ANCASTI \\
#                       CATAMARCA &                          ANDALGALA \\
#                       CATAMARCA &           ANTOFAGASTA DE LA SIERRA \\
#                       CATAMARCA &                              BELEN \\
#                       CATAMARCA &                            CAPAYAN \\
#                       CATAMARCA &                            CAPITAL \\
#                       CATAMARCA &                            EL ALTO \\
#                       CATAMARCA &                FRAY MAMERTO ESQUIU \\
#                       CATAMARCA &                           GUASAYAN \\
#                       CATAMARCA &                             LA PAZ \\
#                       CATAMARCA &                             PACLIN \\
#                       CATAMARCA &                              POMAN \\
#                       CATAMARCA &                        SANTA MARIA \\
#                       CATAMARCA &                         SANTA ROSA \\
#                       CATAMARCA &                          TINOGASTA \\
#                       CATAMARCA &                        VALLE VIEJO \\
#                      ENTRE RIOS &                              COLON \\
#                      ENTRE RIOS &                          CONCORDIA \\
#                      ENTRE RIOS &                           DIAMANTE \\
#                      ENTRE RIOS &                         FEDERACION \\
#                      ENTRE RIOS &                            FEDERAL \\
#                      ENTRE RIOS &                          FELICIANO \\
#                      ENTRE RIOS &                          GUALEGUAY \\
#                      ENTRE RIOS &                       GUALEGUAYCHU \\
#                      ENTRE RIOS &                   ISLAS DEL IBICUY \\
#                      ENTRE RIOS &                             LA PAZ \\
#                      ENTRE RIOS &                             NOGOYA \\
#                      ENTRE RIOS &                             PARANA \\
#                      ENTRE RIOS &                       SAN SALVADOR \\
#                      ENTRE RIOS &                               TALA \\
#                      ENTRE RIOS &                            URUGUAY \\
#                      ENTRE RIOS &                           VICTORIA \\
#                      ENTRE RIOS &                          VILLAGUAY \\
#                        MISIONES &                         25 DE MAYO \\
#                        MISIONES &                          APOSTOLES \\
#                        MISIONES &                           CAINGUAS \\
#                        MISIONES &                         CANDELARIA \\
#                        MISIONES &                            CAPITAL \\
#                        MISIONES &                         CONCEPCION \\
#                        MISIONES &                           ELDORADO \\
#                        MISIONES &            GENERAL MANUEL BELGRANO \\
#                        MISIONES &                            GUARANI \\
#                        MISIONES &                             IGUAZU \\
#                        MISIONES &                    LEANDRO N. ALEM \\
#                        MISIONES &      LIBERTADOR GENERAL SAN MARTIN \\
#                        MISIONES &                         MONTECARLO \\
#                        MISIONES &                              OBERA \\
#                        MISIONES &                        SAN IGNACIO \\
#                        MISIONES &                         SAN JAVIER \\
#                        MISIONES &                          SAN PEDRO \\
#                         TUCUMAN &                          BURRUYACU \\
#                         TUCUMAN &                            CAPITAL \\
#                         TUCUMAN &                        CHICLIGASTA \\
#                         TUCUMAN &                          CRUZ ALTA \\
#                         TUCUMAN &                           FAMAILLA \\
#                         TUCUMAN &                           GRANEROS \\
#                         TUCUMAN &              JUAN BAUTISTA ALBERDI \\
#                         TUCUMAN &                           LA COCHA \\
#                         TUCUMAN &                             LEALES \\
#                         TUCUMAN &                              LULES \\
#                         TUCUMAN &                           MONTEROS \\
#                         TUCUMAN &                          RIO CHICO \\
#                         TUCUMAN &                             SIMOCA \\
#                         TUCUMAN &                     TAFI DEL VALLE \\
#                         TUCUMAN &                         TAFI VIEJO \\
#                         TUCUMAN &                            TRANCAS \\
#                         TUCUMAN &                        YERBA BUENA \\
#                           JUJUY &                          COCHINOCA \\
#                           JUJUY &                DR. MANUEL BELGRANO \\
#                           JUJUY &                          EL CARMEN \\
#                           JUJUY &                          HUMAHUACA \\
#                           JUJUY &                            LEDESMA \\
#                           JUJUY &                            PALPALA \\
#                           JUJUY &                          RINCONADA \\
#                           JUJUY &                        SAN ANTONIO \\
#                           JUJUY &                          SAN PEDRO \\
#                           JUJUY &                      SANTA BARBARA \\
#                           JUJUY &                     SANTA CATALINA \\
#                           JUJUY &                            SUSQUES \\
#                           JUJUY &                            TILCARA \\
#                           JUJUY &                            TUMBAYA \\
#                           JUJUY &                       VALLE GRANDE \\
#                           JUJUY &                               YAVI \\
#                         NEUQUEN &                            ALUMINE \\
#                         NEUQUEN &                              AÑELO \\
#                         NEUQUEN &                          CATAN LIL \\
#                         NEUQUEN &                         CHOS MALAL \\
#                         NEUQUEN &                        COLLON CURA \\
#                         NEUQUEN &                        CONFLUENCIA \\
#                         NEUQUEN &                          HUILICHES \\
#                         NEUQUEN &                              LACAR \\
#                         NEUQUEN &                           LONCOPUE \\
#                         NEUQUEN &                          LOS LAGOS \\
#                         NEUQUEN &                              MINAS \\
#                         NEUQUEN &                         PEHUENCHES \\
#                         NEUQUEN &                        PICUN LEUFU \\
#                         NEUQUEN &                          PICUNCHES \\
#                         NEUQUEN &                             ZAPALA \\
#                         NEUQUEN &                            ÑORQUIN \\
#                          CHUBUT &                             BIEDMA \\
#                          CHUBUT &                           CUSHAMEN \\
#                          CHUBUT &                          ESCALANTE \\
#                          CHUBUT &                FLORENTINO AMEGHINO \\
#                          CHUBUT &                          FUTALEUFU \\
#                          CHUBUT &                             GAIMAN \\
#                          CHUBUT &                             GASTRE \\
#                          CHUBUT &                          LANGUIÑEO \\
#                          CHUBUT &                           MARTIRES \\
#                          CHUBUT &                     PASO DE INDIOS \\
#                          CHUBUT &                             RAWSON \\
#                          CHUBUT &                        RIO SENGUER \\
#                          CHUBUT &                          SARMIENTO \\
#                          CHUBUT &                         TEHUELCHES \\
#                          CHUBUT &                             TELSEN \\
#                       RIO NEGRO &                         25 DE MAYO \\
#                       RIO NEGRO &                         9 DE JULIO \\
#                       RIO NEGRO &                      ADOLFO ALSINA \\
#                       RIO NEGRO &                         AVELLANEDA \\
#                       RIO NEGRO &                          BARILOCHE \\
#                       RIO NEGRO &                             BIEDMA \\
#                       RIO NEGRO &                             CONESA \\
#                       RIO NEGRO &                             EL CUY \\
#                       RIO NEGRO &                       GENERAL ROCA \\
#                       RIO NEGRO &                      PICHI MAHUIDA \\
#                       RIO NEGRO &                         PILCANIYEU \\
#                       RIO NEGRO &                        SAN ANTONIO \\
#                       RIO NEGRO &                           VALCHETA \\
#                       RIO NEGRO &                          ÑORQUINCO \\
#                        SAN LUIS &                           AYACUCHO \\
#                        SAN LUIS &                           BELGRANO \\
#                        SAN LUIS &                          CHACABUCO \\
#                        SAN LUIS &                   CORONEL PRINGLES \\
#                        SAN LUIS &                  GENERAL PEDERNERA \\
#                        SAN LUIS &                   GOBERNADOR DUPUY \\
#                        SAN LUIS &             JUAN MARTIN PUEYRREDON \\
#                        SAN LUIS &                              JUNIN \\
#                        SAN LUIS &                         LA CAPITAL \\
#                        SAN LUIS &      LIBERTADOR GENERAL SAN MARTIN \\
#                         FORMOSA &                            BERMEJO \\
#                         FORMOSA &                            FORMOSA \\
#                         FORMOSA &                             LAISHI \\
#                         FORMOSA &                            MATACOS \\
#                         FORMOSA &                             PATIÑO \\
#                         FORMOSA &                            PILAGAS \\
#                         FORMOSA &                          PILCOMAYO \\
#                         FORMOSA &                             PIRANE \\
#                         FORMOSA &                        RAMON LISTA \\
#                      SANTA CRUZ &                        CORPEN AIKE \\
#                      SANTA CRUZ &                            DESEADO \\
#                      SANTA CRUZ &                          GÜER AIKE \\
#                      SANTA CRUZ &                     LAGO ARGENTINO \\
#                      SANTA CRUZ &                  LAGO BUENOS AIRES \\
#                      SANTA CRUZ &                         MAGALLANES \\
#                      SANTA CRUZ &                          RIO CHICO \\
#                TIERRA DEL FUEGO &            ISLAS DEL ATLANTICO SUR \\
#                TIERRA DEL FUEGO &                         RIO GRANDE \\
#                TIERRA DEL FUEGO &                            USHUAIA \\
# CIUDAD AUTONOMA DE BUENOS AIRES &    CIUDAD AUTONOMA DE BUENOS AIRES \\
# \bottomrule
# \end{tabular}
# C:\Users\luisr\AppData\Local\Temp\ipykernel_16792\4273561937.py:4: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   tabla_latex = tabla.to_latex(index=False)
